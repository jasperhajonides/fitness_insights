# %%
import fitdecode
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
# root_path = '/Users/jasperhajonides/Documents/fitness_insights/'

root_path = '/Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/'
os.chdir(root_path)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
from fitness_insights.extraction.fit_import import LoadFitFiles

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # actually load the fit file

# %%
lff = LoadFitFiles(directory= root_path + 'data/garmin_test_data/')
df_all_fits = lff.get_fit_data()
# Out:
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/extraction/fit_import.py:86: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_all_fits['elapsed_time'] = (df_all_fits['timestamp'] - df_all_fits['timestamp'].min()).dt.total_seconds()

# %%
lff.dropdown_selection(df_all_fits)
df = lff.df_subset
# Out:
# Dropdown(options=('training_2023-06-28-12-20-08.fit', 'cycling_2023-06-26-18-56-33.fit', 'swimming_2023-06-25-…

# %%
df = df_all_fits.loc[df_all_fits.file=='swimming_2023-06-28-17-15-32.fit']

# %%
df = lff.df_subset

# %% [markdown]
# # upload fit file

# %% [markdown]
# # CYCLING

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'].dropna())
df.loc['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Drop rows with invalid datetime values (e.g., 'NaT')
df.dropna(subset=['timestamp'], inplace=True)
# Out:
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/4059532847.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/4059532847.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/4059532847.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.lactate_threshold_autodetect_enabled.unique()
# Out:
# array([nan], dtype=object)

# %%
        gain = df.enhanced_altitude.dropna().diff()
        elevation_gain = int(sum(gain[gain>0]))

# %%
df_sel = df.dropna(subset='enhanced_speed')

# %%
windows = [1,5,10,30,60,120,300,600,1800, 6000]
highest_sum = np.zeros(len(windows))
time_series = df_sel.enhanced_speed
for w, window in enumerate(windows):
#     window = 180
    # Iterate through the time series to calculate sums
    for i in range(len(time_series) - (window-1)):  # Subtract 2 to ensure 3 neighbors are considered
        current_sum = sum(time_series[i:(i+window)])/window

        # Check if the current sum is higher than the highest sum found so far
        if current_sum > highest_sum[w]:
            highest_sum[w] = current_sum
            indices_of_highest_sum = np.arange(i, (i+window))

plt.plot(highest_sum*3.6)
plt.xticks(np.arange(len(windows)),labels=[str(w) for w in windows])
plt.title('speed curve')
plt.xlabel('time of interval')
plt.ylabel('speed in km/h')
# Out:
# Text(0, 0.5, 'speed in km/h')

# %%
highest_sum
# Out:
# array([13.912     , 13.5594    , 13.1534    , 12.20673333, 11.17398333,
#        10.57674167, 10.16936   ,  9.57332167,  9.22968722,  0.        ])

# %%
highest_sum*3.6
# Out:
# 36.420619999999985

# %%
plt.plot(df.elapsed_time,df.enhanced_altitude)

# %%
# Out:
# 8752    1097.0
# Name: total_calories, dtype: object

# %%
# df['timestamp'] = pd.to_datetime(pd.to_datetime('today').date().strftime('%Y-%m-%d ') + df['timestamp'].astype(str))

df.loc[:,'start_time_of_day'] = (pd.to_datetime(df['timestamp']) + pd.to_timedelta(3600, unit='s')).dt.time
df.loc[:,'activity_minutes'] = df['timestamp'].dt.minute 

df_cycle = df.dropna(subset='heart_rate').dropna(axis=1).copy()
df_cycle['elapsed_time'] = df_cycle['elapsed_time'] - df_cycle['elapsed_time'].min()
# Out:
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/1654548705.py:3: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/1654548705.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/1654548705.py:4: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/1654548705.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.plot(df_cycle.enhanced_speed*3.6)

# %%
fig, ax = plt.subplots(figsize=(12, 8))


ax.plot(df_cycle['distance'].head(2000).tail(500),df_cycle['heart_rate'].diff().rolling(window=8, min_periods=3).mean().head(2000).tail(500),color='green')
ax2 = ax.twinx()

ax2.plot(df_cycle['distance'].head(2000).tail(500), df_cycle['heart_rate'].head(2000).tail(500))

# %%
fig, ax = plt.subplots(figsize=(12, 8))

ax.bar(df_cycle['elapsed_time']/60, df_cycle['enhanced_altitude'],color='lightgrey')
ax.set_ylim([0, df_cycle['enhanced_altitude'].max()*3])

ax2 = ax.twinx()

ax2.plot(df_cycle['elapsed_time']/60, df_cycle['heart_rate'])

# %%
import numpy as np
from scipy.optimize import minimize

def fun(params, x):
    a, b, c = params
    return a*np.power((x*b)/155,c) - (.001+0.002*np.power((x)/155,10))

def cost(params):
    a, b, c = params  # corrected this line
    x_values = np.array([120, 155, 180, 190, 195])
    y_values = np.array([-1/3600, 1/3600, 1/180, 1/45, 1/10])
    return np.sum((fun(params, x_values) - y_values) ** 2)

initial_guess = [0.001, 1.03, 15]
result = minimize(cost, initial_guess)

optimized_params = result.x
print(f"Optimized parameters: {optimized_params}")
# Out:
# Optimized parameters: [1.46977152e-03 8.87006389e-01 4.01393873e+01]

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Sample data: Pandas DataFrame with longitude and latitude
df = pd.DataFrame({
    'longitude': [-100.0, -90.0, -80.0, -85.0],
    'latitude': [40.0, 35.0, 30.0, 25.0]
})

# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# Import the world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plotting
fig, ax = plt.subplots(figsize=(10, 15))

# Plot the world map
world.plot(ax=ax, color='lightgrey')

# Plot the points
gdf.plot(ax=ax, marker='o', color='red', markersize=50)

# Plot the lines connecting the points
gdf['geometry'].plot(ax=ax, linestyle='-', color='blue', linewidth=2)

plt.show()
# Out:
#       fun: 0.0036841057934437274
#  hess_inv: array([[ 6.99828736e-11, -2.43802113e-04,  1.88242648e-06],
#        [-2.43802113e-04,  8.96868171e+02, -7.05057363e+00],
#        [ 1.88242648e-06, -7.05057363e+00,  1.05460335e+00]])
#       jac: array([-4.76237238e+03, -2.50127143e-03, -2.28011137e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 547
#       nit: 47
#      njev: 134
#    status: 2
#   success: False
#         x: array([9.35844519e-08, 4.31423971e+00, 1.49893400e+01])

# %% [markdown]
# # cycling geopandas

# %%
    x = df['position_long']
    y = df['position_lat']

# %%
df[['position_long','position_lat']].dropna()
# Out:
#       position_long  position_lat
# 25       -2285024.0   614853407.0
# 31       -2280407.0   614849125.0
# 33       -2279281.0   614848255.0
# 39       -2272832.0   614844297.0
# 41       -2271532.0   614843584.0
# ...             ...           ...
# 8499     -2286815.0   614854583.0
# 8502     -2288073.0   614855904.0
# 8505     -2289707.0   614857181.0
# 8508     -2290616.0   614857948.0
# 8514     -2294914.0   614860484.0
#
# [2175 rows x 2 columns]

# %%
# Out:
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/3871004672.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['logitude'] = df['position_long'].apply(lambda x: semicircle_to_degrees(x))
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/3871004672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['logitude'] = df['position_long'].apply(lambda x: semicircle_to_degrees(x))

# %%
df['logitude'].dropna()
# Out:
# 25     -0.191528
# 31     -0.191142
# 33     -0.191047
# 39     -0.190507
# 41     -0.190398
#           ...
# 8499   -0.191679
# 8502   -0.191784
# 8505   -0.191921
# 8508   -0.191997
# 8514   -0.192357
# Name: logitude, Length: 2175, dtype: float64

# %%
def semicircle_to_degrees(semicircle):
    return semicircle * (180 / (2 ** 31))

latitude_semicircle = -2285024.0
longitude_semicircle = 614853407.0

latitude_degrees = semicircle_to_degrees(latitude_semicircle)
longitude_degrees = semicircle_to_degrees(longitude_semicircle)

print(f"Latitude in degrees: {latitude_degrees}")
print(f"Longitude in degrees: {longitude_degrees}")
# Out:
# Latitude in degrees: -0.19152849912643433
# Longitude in degrees: 51.53641722165048

# %%
x.unique()[2]* (180 / 2^31)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x.unique()[2]* (180 / 2^31)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Sample data: Pandas DataFrame with longitude and latitude


# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.position_long, df.position_lat))

# Import the world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Find the bounds of your points
x_min, x_max = df['position_long'].min() - 1, df['position_long'].max() + 1  # adding/subtracting 1 to add some margin
y_min, y_max = df['position_lat'].min() - 1, df['position_lat'].max() + 1

# Plotting
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the world map
world.plot(ax=ax, color='lightgrey')
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])

# Plot the points
gdf.plot(ax=ax, marker='o', color='red', markersize=2)

# Plot the lines connecting the points
gdf['geometry'].plot(ax=ax, linestyle='-', color='blue', linewidth=2)

plt.show()
# Out:
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78029/2441376564.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-1.6.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: geopandas>=0.12 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from osmnx) (0.13.2)
# Collecting networkx>=2.5 (from osmnx)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: numpy>=1.20 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from osmnx) (1.25.0)
# Requirement already satisfied: pandas>=1.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from osmnx) (2.0.3)
# Requirement already satisfied: requests>=2.27 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from osmnx) (2.29.0)
# Requirement already satisfied: shapely>=2.0 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from osmnx) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from geopandas>=0.12->osmnx) (1.9.4.post1)
# Requirement already satisfied: packaging in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from geopandas>=0.12->osmnx) (23.0)
# Requirement already satisfied: pyproj>=3.0.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from geopandas>=0.12->osmnx) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from pandas>=1.1->osmnx) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from pandas>=1.1->osmnx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from requests>=2.27->osmnx) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from requests>=2.27->osmnx) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from requests>=2.27->osmnx) (2023.7.22)
# Requirement already satisfied: attrs>=19.2.0 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (22.1.0)
# Requirement already satisfied: click~=8.0 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Installing collected packages: networkx, osmnx
# Successfully installed networkx-3.1 osmnx-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import pandas as pd

# Sample data: Pandas DataFrame with longitude and latitude
df2 = pd.DataFrame({
    'longitude': [-100.0, -90.0, -80.0],
    'latitude': [40.0, 35.0, 30.0]
})

# Calculate the bounding box
north = df2['latitude'].max()
south = df2['latitude'].min()
east = df2['longitude'].max()
west = df2['longitude'].min()

# Download the map as a graph
G = ox.graph_from_bbox(north, south, east, west, network_type='all')

# Plot the graph
ox.plot_graph(G)

# %% [markdown]
# # SWIMMING

# %%
from fitness_insights.swimming_analysis import *
from fitness_insights.swimming_visualisation import *

# %%
lff = LoadFitFiles(directory= root_path + 'data/garmin_test_data/')
df_all_fits = lff.get_fit_data()
# Out:
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/extraction/fit_import.py:86: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_all_fits['elapsed_time'] = (df_all_fits['timestamp'] - df_all_fits['timestamp'].min()).dt.total_seconds()

# %%
lff.dropdown_selection(df_all_fits)
# Out:
# Dropdown(options=('training_2023-06-28-12-20-08.fit', 'cycling_2023-06-26-18-56-33.fit', 'swimming_2023-06-25-…

# %%
df = lff.df_subset.copy()
print(df.time_created.unique()[0])
# Out:
# 2023-06-21 17:24:20

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# # Get all the swimming dataframes

# %%
df_laps = df.loc[df.event.isin(['length','lap'])]
df_laps = set_swimlap_indices(df_laps)
# Out:
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:16: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:17: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df_laps = set_swimlap_indices(df)

df_hr = df.dropna(subset='heart_rate')[['elapsed_time','heart_rate']]

# get heart rate epochs
distance_data = obtain_hr_epochs(df_hr, df_laps)
# Out:
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig, ax = plt.subplots(3,1,figsize=(8,15))

plot_all_reps_swimset(df_laps, df_hr, ax[0])
plot_avg_paces(df_laps,ax[1])
plot_hr_intervals(distance_data,ax[2],distance=100)

# %%
df.file.unique()
# Out:
# array(['swimming_2023-06-21-18-24-20.fit'], dtype=object)

# %% [markdown]
# # adapt paceplot code for website

# %%
# Out:
# 10774    False
# 937      False
# 1578     False
# 1713     False
# 1887     False
# 2025     False
# 2200     False
# 2336     False
# 2504     False
# 2642     False
# 2806     False
# 2941     False
# 3768     False
# 3907     False
# 4080     False
# 4222     False
# 4396     False
# 4534     False
# 4702     False
# 4843     False
# 5013     False
# 5155     False
# 5895     False
# 6034     False
# 6194     False
# 6336     False
# 6500     False
# 6649     False
# 7009     False
# 7161     False
# 7330     False
# 7480     False
# 8439     False
# 8749     False
# 8752     False
# 483       True
# 484       True
# 485       True
# 486       True
# 487       True
# 488       True
# 489       True
# 490       True
# 491       True
# 492       True
# 756       True
# 757       True
# 758       True
# 759       True
# 760       True
# 761       True
# 762       True
# 846       True
# 847       True
# 921       True
# 922       True
# 923       True
# 973       True
# 974       True
# 1049      True
# 1050      True
# 1051      True
# 1085      True
# 1086      True
# 1160      True
# 1161      True
# 1162      True
# 1210      True
# 1211      True
# 1287      True
# 1288      True
# 1289      True
# 1429      True
# 1430      True
# 1858      True
# 1859      True
# 1860      True
# 1861      True
# 1862      True
# 1863      True
# 1864      True
# 1865      True
# 1866      True
# 1867      True
# 2284      True
# 2285      True
# 2286      True
# 2287      True
# 2288      True
# 2289      True
# 2290      True
# 2291      True
# 2292      True
# 2293      True
# 2675      True
# 2676      True
# 2677      True
# 2678      True
# 2679      True
# 2680      True
# 2681      True
# 2682      True
# 2683      True
# 3112      True
# 3113      True
# 3114      True
# 3115      True
# 3116      True
# 3117      True
# 3118      True
# 3119      True
# 3120      True
# 3121      True
# 3501      True
# 3502      True
# 3503      True
# 3504      True
# 3505      True
# 3506      True
# 3507      True
# 3508      True
# 3509      True
# 3903      True
# 3904      True
# 3905      True
# 3906      True
# 3907      True
# 3908      True
# 3909      True
# 3910      True
# 3911      True
# 4027      True
# 4028      True
# 4029      True
# 4030      True
# 4273      True
# 4274      True
# 4463      True
# 4464      True
# 4465      True
# 4466      True
# 4666      True
# 4667      True
# 4675      True
# 4676      True
# 4684      True
# 4685      True
# 5127      True
# 5128      True
# 5129      True
# 5130      True
# 5131      True
# 5132      True
# 5133      True
# 5134      True
# 5135      True
# 5136      True
# 5569      True
# 5570      True
# 5571      True
# 5572      True
# 5573      True
# 5574      True
# 5575      True
# 5576      True
# 5577      True
# 5578      True
# 5742      True
# 5743      True
# 5744      True
# 5745      True
# 5746      True
# 5900      True
# 5901      True
# 6094      True
# 6095      True
# 6096      True
# 6097      True
# 6098      True
# 6126      True
# 6127      True
# 6565      True
# 6566      True
# 6567      True
# 6568      True
# 6569      True
# 6570      True
# 6571      True
# 6572      True
# 6573      True
# 6574      True
# 6952      True
# 6953      True
# 6954      True
# 6955      True
# 6956      True
# 6957      True
# 6958      True
# 6959      True
# 7209      True
# 7210      True
# 7211      True
# 7212      True
# 7213      True
# 7214      True
# 7215      True
# 7377      True
# 7378      True
# 7560      True
# 7561      True
# 7562      True
# 7563      True
# 7564      True
# 7586      True
# 7592      True
# 11325     True
# 3928     False
# 519       True
# 520       True
# 521       True
# 522       True
# 523       True
# 524       True
# 525       True
# 526       True
# 527       True
# 528       True
# 529       True
# 732       True
# 733       True
# 734       True
# 735       True
# 736       True
# 737       True
# 879       True
# 880       True
# 1047      True
# 1048      True
# 1049      True
# 1050      True
# 1051      True
# 1103      True
# 1104      True
# 1268      True
# 1269      True
# 1270      True
# 1271      True
# 1272      True
# 1324      True
# 1325      True
# 1477      True
# 1478      True
# 1479      True
# 1480      True
# 1481      True
# 1545      True
# 1546      True
# 1701      True
# 1702      True
# 1703      True
# 1704      True
# 1705      True
# 1787      True
# 1788      True
# 1866      True
# 1867      True
# 1868      True
# 1917      True
# 1918      True
# 1994      True
# 1995      True
# 1996      True
# 2042      True
# 2043      True
# 2119      True
# 2120      True
# 2121      True
# 2173      True
# 2174      True
# 2248      True
# 2249      True
# 2250      True
# 2344      True
# 2345      True
# 2502      True
# 2503      True
# 2504      True
# 2505      True
# 2506      True
# 2547      True
# 2548      True
# 2707      True
# 2708      True
# 2709      True
# 2710      True
# 2711      True
# 2757      True
# 2758      True
# 2913      True
# 2914      True
# 2915      True
# 2916      True
# 2917      True
# 2969      True
# 2970      True
# 3122      True
# 3123      True
# 3124      True
# 3125      True
# 3126      True
# 3197      True
# 3198      True
# 3525      True
# 3526      True
# 3527      True
# 3528      True
# 3529      True
# 3530      True
# 3531      True
# 3532      True
# 3533      True
# 3613      True
# 3614      True
# 3941      True
# 3942      True
# 3943      True
# 3944      True
# 3945      True
# 3946      True
# 3947      True
# 3948      True
# 3949      True
# 4083      True
# 4084      True
# 4472      True
# 4473      True
# 4474      True
# 4475      True
# 4476      True
# 4477      True
# 4478      True
# 4479      True
# 4480      True
# 4758      True
# 4759      True
# 4760      True
# 4761      True
# 4762      True
# 4763      True
# 4764      True
# 4765      True
# 4931      True
# 4932      True
# 5094      True
# 5095      True
# 5096      True
# 5097      True
# 5098      True
# 5148      True
# 5149      True
# 5310      True
# 5311      True
# 5312      True
# 5313      True
# 5314      True
# 5370      True
# 5371      True
# 5530      True
# 5531      True
# 5532      True
# 5533      True
# 5534      True
# 5596      True
# 5597      True
# 5759      True
# 5760      True
# 5761      True
# 5762      True
# 5763      True
# 5851      True
# 5852      True
# 6189      True
# 6190      True
# 6191      True
# 6192      True
# 6193      True
# 6194      True
# 6195      True
# 6196      True
# 6197      True
# 6298      True
# 6299      True
# 6631      True
# 6632      True
# 6633      True
# 6634      True
# 6635      True
# 6636      True
# 6637      True
# 6638      True
# 6639      True
# 6723      True
# 6724      True
# 7165      True
# 7166      True
# 7167      True
# 7168      True
# 7169      True
# 7170      True
# 7171      True
# 7172      True
# 7173      True
# 7174      True
# 7412      True
# 7413      True
# 7414      True
# 7415      True
# 7416      True
# 7417      True
# 7418      True
# 7529      True
# 7530      True
# 7719      True
# 7720      True
# 7721      True
# 7722      True
# 7723      True
# 7779      True
# 7780      True
# 8258      True
# 8259      True
# 8260      True
# 8261      True
# 8262      True
# 8263      True
# 8264      True
# 8265      True
# 8266      True
# 8267      True
# 8527      True
# 8528      True
# 8529      True
# 8530      True
# 8531      True
# 8532      True
# 8533      True
# 8583      True
# 8584      True
# 8773      True
# 8774      True
# 8775      True
# 8776      True
# 8777      True
# 8797      True
# 8803      True
# 9088      True
# 1221     False
# 2384     False
# 3813     False
# 5082     False
# 6425     False
# 8952     False
# 9898     False
# 11468    False
# 15725    False
# 15728    False
# 1133     False
# 1805     False
# 2486     False
# 3183     False
# 3934     False
# 4634     False
# 5398     False
# 6968     False
# 6971     False
# 481       True
# 482       True
# 483       True
# 484       True
# 485       True
# 486       True
# 487       True
# 488       True
# 489       True
# 490       True
# 726       True
# 727       True
# 728       True
# 729       True
# 730       True
# 731       True
# 749       True
# 750       True
# 760       True
# 761       True
# 781       True
# 782       True
# 863       True
# 864       True
# 865       True
# 903       True
# 904       True
# 982       True
# 983       True
# 984       True
# 1030      True
# 1031      True
# 1113      True
# 1114      True
# 1115      True
# 1145      True
# 1146      True
# 1222      True
# 1223      True
# 1224      True
# 1250      True
# 1251      True
# 1581      True
# 1582      True
# 1583      True
# 1584      True
# 1585      True
# 1586      True
# 1587      True
# 1588      True
# 1589      True
# 1637      True
# 1638      True
# 1959      True
# 1960      True
# 1961      True
# 1962      True
# 1963      True
# 1964      True
# 1965      True
# 1966      True
# 1967      True
# 2027      True
# 2028      True
# 2360      True
# 2361      True
# 2362      True
# 2363      True
# 2364      True
# 2365      True
# 2366      True
# 2367      True
# 2368      True
# 2428      True
# 2429      True
# 2759      True
# 2760      True
# 2761      True
# 2762      True
# 2763      True
# 2764      True
# 2765      True
# 2766      True
# 2767      True
# 2849      True
# 2850      True
# 3177      True
# 3178      True
# 3179      True
# 3180      True
# 3181      True
# 3182      True
# 3183      True
# 3184      True
# 3185      True
# 3237      True
# 3238      True
# 3566      True
# 3567      True
# 3568      True
# 3569      True
# 3570      True
# 3571      True
# 3572      True
# 3573      True
# 3574      True
# 3644      True
# 3645      True
# 3978      True
# 3979      True
# 3980      True
# 3981      True
# 3982      True
# 3983      True
# 3984      True
# 3985      True
# 3986      True
# 4030      True
# 4031      True
# 4373      True
# 4374      True
# 4375      True
# 4376      True
# 4377      True
# 4378      True
# 4379      True
# 4380      True
# 4381      True
# 4437      True
# 4438      True
# 4763      True
# 4764      True
# 4765      True
# 4766      True
# 4767      True
# 4768      True
# 4769      True
# 4770      True
# 4771      True
# 4827      True
# 4828      True
# 5163      True
# 5164      True
# 5165      True
# 5166      True
# 5167      True
# 5168      True
# 5169      True
# 5170      True
# 5171      True
# 5398      True
# 5399      True
# 5571      True
# 5572      True
# 5573      True
# 5574      True
# 5575      True
# 5645      True
# 5646      True
# 5823      True
# 5824      True
# 5825      True
# 5826      True
# 5827      True
# 5995      True
# 5996      True
# 6548      True
# 6549      True
# 6550      True
# 6551      True
# 6552      True
# 6553      True
# 6554      True
# 6555      True
# 6556      True
# 6626      True
# 6627      True
# 7191      True
# 7192      True
# 7193      True
# 7194      True
# 7195      True
# 7196      True
# 7197      True
# 7198      True
# 7199      True
# 7293      True
# 7294      True
# 7466      True
# 7467      True
# 7468      True
# 7469      True
# 7470      True
# 7799      True
# 7800      True
# 8282      True
# 8283      True
# 8284      True
# 8285      True
# 8286      True
# 8287      True
# 8288      True
# 8289      True
# 8290      True
# 8291      True
# 8550      True
# 8551      True
# 8552      True
# 8553      True
# 8554      True
# 8555      True
# 8556      True
# 8672      True
# 8673      True
# 8863      True
# 8864      True
# 8865      True
# 8866      True
# 8867      True
# 9200      True
# 9207      True
# 9594      True
# 6691     False
# 670      False
# 978      False
# 1404     False
# 2111     False
# 2746     False
# 2758     False
# 3050     False
# 493       True
# 494       True
# 495       True
# 496       True
# 497       True
# 498       True
# 499       True
# 500       True
# 501       True
# 502       True
# 768       True
# 769       True
# 770       True
# 771       True
# 772       True
# 773       True
# 774       True
# 1305      True
# 1306      True
# 1394      True
# 1395      True
# 1396      True
# 1436      True
# 1437      True
# 1535      True
# 1536      True
# 1537      True
# 1567      True
# 1568      True
# 1658      True
# 1659      True
# 1660      True
# 1709      True
# 1710      True
# 1794      True
# 1795      True
# 1796      True
# 2166      True
# 2167      True
# 2253      True
# 2254      True
# 2255      True
# 2330      True
# 2331      True
# 2425      True
# 2426      True
# 2427      True
# 2459      True
# 2460      True
# 2552      True
# 2553      True
# 2554      True
# 2606      True
# 2607      True
# 2691      True
# 2692      True
# 2693      True
# 3609      True
# 3610      True
# 3769      True
# 3770      True
# 3771      True
# 3772      True
# 3773      True
# 3819      True
# 3820      True
# 4063      True
# 4064      True
# 4065      True
# 4066      True
# 4076      True
# 4077      True
# 4152      True
# 4153      True
# 4167      True
# 4168      True
# 4328      True
# 4329      True
# 4330      True
# 4331      True
# 4332      True
# 4398      True
# 4399      True
# 4662      True
# 4663      True
# 4664      True
# 4665      True
# 4666      True
# 4712      True
# 4713      True
# 4877      True
# 4878      True
# 4879      True
# 4880      True
# 4881      True
# 5071      True
# 5072      True
# 5367      True
# 5368      True
# 5369      True
# 5370      True
# 5371      True
# 5424      True
# 5425      True
# 5571      True
# 5572      True
# 5573      True
# 5574      True
# 5602      True
# 5603      True
# 5647      True
# 5648      True
# 5668      True
# 5669      True
# 5850      True
# 5851      True
# 5852      True
# 5874      True
# 5875      True
# 6081      True
# 6082      True
# 6083      True
# 6084      True
# 6092      True
# 6093      True
# 6296      True
# 6297      True
# 6298      True
# 6299      True
# 6371      True
# 6372      True
# 6522      True
# 6523      True
# 6524      True
# 6525      True
# 6634      True
# 6635      True
# 6835      True
# 6836      True
# 6837      True
# 6838      True
# 7022      True
# 7023      True
# 7123      True
# 7124      True
# 7125      True
# 7175      True
# 7176      True
# 7311      True
# 7312      True
# 7313      True
# 7505      True
# 7506      True
# 7602      True
# 7603      True
# 7604      True
# 7953      True
# 7954      True
# 8138      True
# 8139      True
# 8140      True
# 8282      True
# 8283      True
# 8382      True
# 8383      True
# 8384      True
# 8410      True
# 8411      True
# 8557      True
# 8558      True
# 8559      True
# 8743      True
# 8744      True
# 8800      True
# 8801      True
# 8861      True
# 8862      True
# 8914      True
# 8915      True
# 8949      True
# 8950      True
# 9008      True
# 9009      True
# 9019      True
# 9020      True
# 9064      True
# 9065      True
# 9174      True
# 9175      True
# 9231      True
# 9232      True
# 9254      True
# 9255      True
# 9299      True
# 9300      True
# 9496      True
# 9497      True
# 9587      True
# 9588      True
# 9589      True
# 10429     True
# 10436     True
# 12367     True
# 12374     True
# 12399     True
# 2587     False
# 2235     False
# Name: file, dtype: bool

# %%
df_filtered.loc[].dropna(axis=1)['file']
# Out:
# array(['swimming_2023-06-25-17-32-00.fit',
#        'swimming_2023-07-14-17-03-50.fit',
#        'swimming_2023-06-28-17-15-32.fit',
#        'swimming_2023-06-23-16-46-38.fit'], dtype=object)

# %%
df_laps = set_swimlap_indices(df_all_fits.loc[df_all_fits['file'] =='swimming_2023-06-28-17-15-32.fit' ])
# Out:
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:16: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/jasperhajonides/Documents/FUN/gpt_fitness_coach/fitness_insights/swimming_analysis.py:17: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df_laps.total_distance.unique()
# Out:
# array([  nan,  375.,    0.,   25.,   50.,  200.,  100.,  400., 3800.])

# %%
plt.hist(df_laps.dropna(subset='avg_speed').total_elapsed_time)
# Out:
# (array([ 1.,  0.,  2., 31., 96.,  4.,  9.,  8.,  0.,  1.]),
#  array([ 1.216 ,  5.8407, 10.4654, 15.0901, 19.7148, 24.3395, 28.9642,
#         33.5889, 38.2136, 42.8383, 47.463 ]),
#  <BarContainer object of 10 artists>)

# %%
df_laps.avg_speed.unique()
# Out:
# array([ 1.087,  1.262,  1.278,  1.444,  0.83 ,  1.201,  1.212,  1.031,
#         1.153,  1.102,  1.786,  0.527,    nan, 20.559,  1.124,  1.513,
#         1.14 ,  1.569,  1.156,  1.385,  1.351,  1.176,  1.258,  1.19 ,
#         1.183,  1.143,  1.242,  1.448,  1.274,  1.266,  1.282,  1.286,
#         1.223,  1.461,  1.307,  1.205,  1.198,  1.22 ,  1.039,  1.303,
#         1.372,  1.166,  1.235,  1.17 ,  1.136,  1.365,  1.227,  1.216,
#         1.25 ,  1.332,  1.27 ,  1.133,  1.409,  1.149,  1.231,  1.238,
#         1.163,  1.152,  1.375,  1.194,  1.208,  1.457,  1.047,  1.014,
#         1.105,  1.093,  1.277,  1.072,  1.297,  0.752,  0.729,  1.18 ,
#         1.263,  1.117,  1.099,  1.005,  1.058,  1.108,  0.993,  1.02 ,
#         1.084,  1.111,  1.257,  1.114,  1.044])

# %%
df_laps.loc[df_laps.lap_nr==0]
# Out:
#        sub_sport  total_distance  total_elapsed_time  total_cycles  \
# 0            NaN             NaN              23.000           NaN
# 1            NaN             NaN              19.812           NaN
# 2            NaN             NaN              19.562           NaN
# 3            NaN             NaN              17.312           NaN
# 4            NaN             NaN              30.125           NaN
# 5            NaN             NaN              20.812           NaN
# 6            NaN             NaN              23.000           NaN
# 7            NaN             NaN              20.625           NaN
# 8            NaN             NaN              24.250           NaN
# 9            NaN             NaN              21.687           NaN
# 10           NaN             NaN              22.687           NaN
# 11           NaN             NaN              14.000           NaN
# 12           NaN             NaN              20.625           NaN
# 13           NaN             NaN              19.562           NaN
# 14           NaN             NaN              47.463           NaN
# 15  lap_swimming           375.0             344.522         152.0
#
#     avg_stroke_count  total_calories  avg_speed  num_laps  num_active_lengths  \
# 0                NaN             5.0      1.087       NaN                 NaN
# 1                NaN             5.0      1.262       NaN                 NaN
# 2                NaN             5.0      1.278       NaN                 NaN
# 3                NaN             5.0      1.444       NaN                 NaN
# 4                NaN             5.0      0.830       NaN                 NaN
# 5                NaN             5.0      1.201       NaN                 NaN
# 6                NaN             5.0      1.087       NaN                 NaN
# 7                NaN             5.0      1.212       NaN                 NaN
# 8                NaN             5.0      1.031       NaN                 NaN
# 9                NaN             5.0      1.153       NaN                 NaN
# 10               NaN             5.0      1.102       NaN                 NaN
# 11               NaN             5.0      1.786       NaN                 NaN
# 12               NaN             5.0      1.212       NaN                 NaN
# 13               NaN             5.0      1.278       NaN                 NaN
# 14               NaN             5.0      0.527       NaN                 NaN
# 15               NaN            75.0        NaN       NaN                15.0
#
#     avg_heart_rate swim_stroke  num_lengths  first_length_index  \
# 0              NaN   freestyle          NaN                 NaN
# 1              NaN   freestyle          NaN                 NaN
# 2              NaN   freestyle          NaN                 NaN
# 3              NaN   freestyle          NaN                 NaN
# 4              NaN   freestyle          NaN                 NaN
# 5              NaN   freestyle          NaN                 NaN
# 6              NaN   freestyle          NaN                 NaN
# 7              NaN   freestyle          NaN                 NaN
# 8              NaN   freestyle          NaN                 NaN
# 9              NaN   freestyle          NaN                 NaN
# 10             NaN   freestyle          NaN                 NaN
# 11             NaN   freestyle          NaN                 NaN
# 12             NaN   freestyle          NaN                 NaN
# 13             NaN   freestyle          NaN                 NaN
# 14             NaN   freestyle          NaN                 NaN
# 15           124.0   freestyle         15.0                 0.0
#
#     avg_swimming_cadence  total_strokes length_type  elapsed_time  lap_nr  \
# 0                   23.0            9.0      active      600900.0       0
# 1                   27.0            9.0      active      600900.0       0
# 2                   31.0           10.0      active      600900.0       0
# 3                   31.0            9.0      active      600900.0       0
# 4                   30.0           15.0      active      600900.0       0
# 5                   26.0            9.0      active      600900.0       0
# 6                   29.0           11.0      active      600900.0       0
# 7                   29.0           10.0      active      600900.0       0
# 8                   27.0           11.0      active      600900.0       0
# 9                   30.0           11.0      active      600900.0       0
# 10                  29.0           11.0      active      601016.0       0
# 11                  26.0            6.0      active      601016.0       0
# 12                  29.0           10.0      active      601016.0       0
# 13                  28.0            9.0      active      601016.0       0
# 14                  15.0           12.0      active      601016.0       0
# 15                   NaN            NaN         NaN      601016.0       0
#
#    length_nr   cumsum  start_time  time_interval   SWOLF
# 0          1   23.000  600671.478        344.522  32.000
# 1          2   42.812  600671.478        344.522  28.812
# 2          3   62.374  600671.478        344.522  29.562
# 3          4   79.686  600671.478        344.522  26.312
# 4          5  109.811  600671.478        344.522  45.125
# 5          6  130.623  600671.478        344.522  29.812
# 6          7  153.623  600671.478        344.522  34.000
# 7          8  174.248  600671.478        344.522  30.625
# 8          9  198.498  600671.478        344.522  35.250
# 9         10  220.185  600671.478        344.522  32.687
# 10        11  242.872  600671.478        344.522  33.687
# 11        12  256.872  600671.478        344.522  20.000
# 12        13  277.497  600671.478        344.522  30.625
# 13        14  297.059  600671.478        344.522  28.562
# 14        15  344.522  600671.478        344.522  59.463
# 15      None      NaN  600671.478        344.522     NaN

# %%
df_laps.loc[df_laps.total_distance==375,'lap_nr']
# Out:
# 15    0
# Name: lap_nr, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd

def logarithmic_func(x, a, b, c):
    return a * np.log(b * x) + c

def set_swimlap_indices(df):  # Dummy function for the example
    return df



activity_file = 'swimming_2023-06-21-18-24-20.fit'

all_files = [name for name in df_all_fits['file'].unique() if 'swimming' in name]
other_files = [name for name in all_files if name != activity_file]
only_current_activity = len(other_files) < 2

highest_pace = 0
for is_current_activity, fit_color, avg_color in [(True, 'magenta', 'magenta'),
                                                  (False, 'purple', 'white')]:

    if only_current_activity and not is_current_activity:
        continue

    condition = (df_all_fits['file'] == activity_file) if is_current_activity else (df_all_fits['file'] != activity_file)
    df_filtered = df_all_fits.loc[df_all_fits['event'].isin(['length', 'lap']) & condition & df_all_fits['file'].str.contains('swim')] # add Condition file contains swim
    df_laps = set_swimlap_indices(df_filtered)
    print(df_laps.shape)
    
    # remove faulty total distance numbers
    data_filtered = df_laps[df_laps['total_distance'].notna() & (df_laps['total_distance'] != 0)]
    
    # correct er
    
    #calculate pace
    data_filtered['pace'] = (data_filtered['total_elapsed_time'] * 100) / data_filtered['total_distance']
    
    

    highest_pace = highest_pace if data_filtered['pace'].max() < highest_pace else data_filtered['pace'].max()

    grouped_data = data_filtered.loc[(data_filtered['sub_sport']=='lap_swimming') & (data_filtered['swim_stroke'] != 'drill')].groupby(['total_distance'])['pace'].median()
    selected_distances = [50, 100, 150, 200, 300, 400, 800]
    grouped_data_filtered = grouped_data[grouped_data.index.isin(selected_distances)]

    if grouped_data_filtered.empty:
        continue

    plt.scatter(grouped_data.index, grouped_data.values, c=avg_color, edgecolors='black', label='Average Pace')
    params, _ = curve_fit(logarithmic_func, grouped_data.index, grouped_data.values)
    x_fit = np.linspace(grouped_data.index.min(), grouped_data.index.max(), 100)
    y_fit = logarithmic_func(x_fit, *params)

    plt.plot(x_fit, y_fit, color=fit_color, label='Logarithmic Fit')

y_max = min(int(np.ceil(highest_pace / 10) * 10),150) + 10
tickvals = list(range(0, y_max + 1, 30))
ticktext = [f"{int(val // 60):02d}:{int(val % 60):02d}" for val in tickvals]

plt.ylim([y_max, 30])
plt.yticks(tickvals, ticktext)
plt.xlim([0, 800])
plt.xlabel('Total Distance')
plt.ylabel('Pace (seconds per 100m)')
plt.title('Pace (seconds per 100m) vs Total Distance')
plt.legend()
plt.show()

# Dummy DataFrame and activity file for the example
# df_all_fits = pd.DataFrame(...)
# activity_file = "some_file"

# plot_avg_paces(df_all_fits, activity_file)
# Out:
# (278, 174)
# (847, 174)
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_67038/3690630032.py:38: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_67038/3690630032.py:38: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages/pandas/core/indexes/base.py:911: RuntimeWarning:
#
# invalid value encountered in log
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_67038/3690630032.py:38: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_67038/3690630032.py:38: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages/pandas/core/indexes/base.py:911: RuntimeWarning:
#
# invalid value encountered in log

# %%
df_all_fits['file'].unique()
# Out:
# array(['training_2023-06-28-12-20-08.fit',
#        'cycling_2023-06-26-18-56-33.fit',
#        'swimming_2023-06-25-17-32-00.fit',
#        'training_2023-07-13-12-09-14.fit',
#        'swimming_2023-07-14-17-03-50.fit',
#        'cycling_2023-07-16-11-17-38.fit',
#        'cycling_2023-07-12-18-28-42.fit',
#        'swimming_2023-06-28-17-15-32.fit',
#        'training_2023-06-22-12-11-17.fit',
#        'swimming_2023-06-21-18-24-20.fit',
#        'running_2023-06-23-12-56-43.fit',
#        'training_2023-06-26-12-06-57.fit',
#        'swimming_2023-06-23-16-46-38.fit',
#        'training_2023-06-27-12-08-51.fit',
#        'training_2023-07-11-12-14-30.fit'], dtype=object)

# %%
df = df_all_fits[df_all_fits['file'].str.startswith('swimming')]

# %%
fig, ax = plt.subplots(3,1,figsize=(8,15))


plt.rcParams.update({
    "lines.color": "white",
    "patch.edgecolor": "white",
    "text.color": "white",
    "axes.facecolor": "black",
    "axes.edgecolor": "lightgray",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "grid.color": "lightgray",
    "figure.facecolor": "black",
    "figure.edgecolor": "black",
    "savefig.facecolor": "black",
    "savefig.edgecolor": "black"})

plot_all_reps_swimset(df_laps, df_hr,ax=ax[0])

plot_hr_intervals(distance_data, ax[1], distance = 50)
    
plot_avg_paces(df_laps,ax=ax[2],ylim=[60,120])
# Out:
# /var/folders/nx/9p_nwvbx1_bg15jk8zx5bqb80000gn/T/ipykernel_4150/1387087799.py:128: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('magma_r')

# %% [markdown]
# ## add to dataframe

# %%
lff.dropdown_selection(df_all_fits)
# Out:
# Dropdown(options=('training_2023-06-28-12-20-08.fit', 'cycling_2023-06-26-18-56-33.fit', 'swimming_2023-06-25-…

# %%
pip install hmmlearn
# Out:
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.0-cp311-cp311-macosx_10_9_universal2.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.7/192.7 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from hmmlearn) (1.25.0)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from hmmlearn) (1.2.0)
# Requirement already satisfied: scipy>=0.19 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from hmmlearn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jasperhajonides/miniconda3/envs/garmin/lib/python3.11/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.1.0)
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
df3 = df

# %%
df = lff.df_subset.copy()
print(df.time_created.unique()[0])
# Out:
# 2023-07-12 17:28:43

# %%
[i for i in df.columns if 'alt' in i]
# Out:
# ['enhanced_altitude',
#  'enhanced_avg_altitude',
#  'enhanced_min_altitude',
#  'enhanced_max_altitude']

# %%
df.reset_index(drop=True,inplace=True)
df = df.dropna()

# %%
df = pd.concat([df1,df2,df3])

# %%
df.shape
# Out:
# (17955, 176)

# %%
from hmmlearn import hmm

# df[['heart_rate', 'speed', 'elevation']] = df[['heart_rate', 'speed', 'elevation']].clip(lower=0).apply(int)

# df = lff.df_subset.copy()

df.reset_index(drop=True,inplace=True)
df['elevation_change'] = df.enhanced_altitude.diff()

df = df.dropna(subset=['enhanced_speed', 'heart_rate','elevation_change'])
df = df[['enhanced_speed', 'heart_rate', 'elevation_change']]
observations = df.values

# Define the number of states
n_states = 3

# Create an HMM model with Gaussian emissions
model = hmm.GaussianHMM(n_components=n_states)

# Fit the model to the observations
model.fit(observations)

# Define the minimum duration for each state visit (in number of time points)
min_duration = 30

# Predict the most likely state sequence using the Viterbi algorithm
log_likelihood, state_sequence = model.decode(observations)

# Apply the minimum duration constraint to the state sequence
filtered_state_sequence = []
current_state = state_sequence[0]
current_duration = 1

for i in range(1, len(state_sequence)):
    if state_sequence[i] == current_state:
        current_duration += 1
    else:
        if current_duration >= min_duration:
            filtered_state_sequence.extend([current_state] * current_duration)
        else:
            filtered_state_sequence.extend([state_sequence[i-1]] * current_duration)
        current_state = state_sequence[i]
        current_duration = 1

# Extend the state sequence for the remaining time points
if current_duration >= min_duration:
    filtered_state_sequence.extend([current_state] * current_duration)
else:
    filtered_state_sequence.extend([state_sequence[-1]] * current_duration)

# Add the predicted filtered state sequence to the original dataframe
df['filtered_states'] = filtered_state_sequence

# Print the state sequence for each observation
for i, state in enumerate(filtered_state_sequence):
    print(f"Observation {i+1} is in state {state+1}")
# Out:
# Observation 1 is in state 1
# Observation 2 is in state 1
# Observation 3 is in state 1
# Observation 4 is in state 1
# Observation 5 is in state 1
# Observation 6 is in state 1
# Observation 7 is in state 1
# Observation 8 is in state 1
# Observation 9 is in state 1
# Observation 10 is in state 1
# Observation 11 is in state 1
# Observation 12 is in state 1
# Observation 13 is in state 1
# Observation 14 is in state 1
# Observation 15 is in state 1
# Observation 16 is in state 1
# Observation 17 is in state 1
# Observation 18 is in state 1
# Observation 19 is in state 1
# Observation 20 is in state 1
# Observation 21 is in state 1
# Observation 22 is in state 1
# Observation 23 is in state 1
# Observation 24 is in state 1
# Observation 25 is in state 1
# Observation 26 is in state 1
# Observation 27 is in state 1
# Observation 28 is in state 1
# Observation 29 is in state 1
# Observation 30 is in state 1
# Observation 31 is in state 1
# Observation 32 is in state 1
# Observation 33 is in state 1
# Observation 34 is in state 1
# Observation 35 is in state 1
# Observation 36 is in state 1
# Observation 37 is in state 1
# Observation 38 is in state 1
# Observation 39 is in state 1
# Observation 40 is in state 1
# Observation 41 is in state 1
# Observation 42 is in state 1
# Observation 43 is in state 1
# Observation 44 is in state 1
# Observation 45 is in state 1
# Observation 46 is in state 1
# Observation 47 is in state 1
# Observation 48 is in state 1
# Observation 49 is in state 1
# Observation 50 is in state 1
# Observation 51 is in state 1
# Observation 52 is in state 1
# Observation 53 is in state 1
# Observation 54 is in state 1
# Observation 55 is in state 1
# Observation 56 is in state 1
# Observation 57 is in state 1
# Observation 58 is in state 1
# Observation 59 is in state 1
# Observation 60 is in state 1
# Observation 61 is in state 1
# Observation 62 is in state 1
# Observation 63 is in state 1
# Observation 64 is in state 1
# Observation 65 is in state 1
# Observation 66 is in state 1
# Observation 67 is in state 2
# Observation 68 is in state 2
# Observation 69 is in state 2
# Observation 70 is in state 2
# Observation 71 is in state 2
# Observation 72 is in state 2
# Observation 73 is in state 2
# Observation 74 is in state 2
# Observation 75 is in state 2
# Observation 76 is in state 2
# Observation 77 is in state 2
# Observation 78 is in state 2
# Observation 79 is in state 2
# Observation 80 is in state 2
# Observation 81 is in state 2
# Observation 82 is in state 2
# Observation 83 is in state 2
# Observation 84 is in state 1
# Observation 85 is in state 1
# Observation 86 is in state 1
# Observation 87 is in state 1
# Observation 88 is in state 1
# Observation 89 is in state 1
# Observation 90 is in state 1
# Observation 91 is in state 1
# Observation 92 is in state 1
# Observation 93 is in state 1
# Observation 94 is in state 1
# Observation 95 is in state 1
# Observation 96 is in state 1
# Observation 97 is in state 1
# Observation 98 is in state 1
# Observation 99 is in state 1
# Observation 100 is in state 1
# Observation 101 is in state 1
# Observation 102 is in state 1
# Observation 103 is in state 1
# Observation 104 is in state 1
# Observation 105 is in state 1
# Observation 106 is in state 1
# Observation 107 is in state 1
# Observation 108 is in state 1
# Observation 109 is in state 1
# Observation 110 is in state 1
# Observation 111 is in state 1
# Observation 112 is in state 1
# Observation 113 is in state 1
# Observation 114 is in state 1
# Observation 115 is in state 1
# Observation 116 is in state 1
# Observation 117 is in state 1
# Observation 118 is in state 1
# Observation 119 is in state 1
# Observation 120 is in state 1
# Observation 121 is in state 1
# Observation 122 is in state 1
# Observation 123 is in state 1
# Observation 124 is in state 1
# Observation 125 is in state 1
# Observation 126 is in state 1
# Observation 127 is in state 1
# Observation 128 is in state 1
# Observation 129 is in state 1
# Observation 130 is in state 1
# Observation 131 is in state 1
# Observation 132 is in state 2
# Observation 133 is in state 2
# Observation 134 is in state 2
# Observation 135 is in state 2
# Observation 136 is in state 2
# Observation 137 is in state 2
# Observation 138 is in state 2
# Observation 139 is in state 2
# Observation 140 is in state 2
# Observation 141 is in state 2
# Observation 142 is in state 2
# Observation 143 is in state 2
# Observation 144 is in state 2
# Observation 145 is in state 2
# Observation 146 is in state 2
# Observation 147 is in state 1
# Observation 148 is in state 1
# Observation 149 is in state 1
# Observation 150 is in state 1
# Observation 151 is in state 1
# Observation 152 is in state 1
# Observation 153 is in state 1
# Observation 154 is in state 1
# Observation 155 is in state 2
# Observation 156 is in state 2
# Observation 157 is in state 2
# Observation 158 is in state 2
# Observation 159 is in state 2
# Observation 160 is in state 2
# Observation 161 is in state 2
# Observation 162 is in state 2
# Observation 163 is in state 2
# Observation 164 is in state 2
# Observation 165 is in state 2
# Observation 166 is in state 2
# Observation 167 is in state 2
# Observation 168 is in state 2
# Observation 169 is in state 2
# Observation 170 is in state 2
# Observation 171 is in state 2
# Observation 172 is in state 2
# Observation 173 is in state 2
# Observation 174 is in state 2
# Observation 175 is in state 2
# Observation 176 is in state 2
# Observation 177 is in state 2
# Observation 178 is in state 2
# Observation 179 is in state 2
# Observation 180 is in state 2
# Observation 181 is in state 2
# Observation 182 is in state 2
# Observation 183 is in state 2
# Observation 184 is in state 2
# Observation 185 is in state 2
# Observation 186 is in state 1
# Observation 187 is in state 1
# Observation 188 is in state 1
# Observation 189 is in state 1
# Observation 190 is in state 2
# Observation 191 is in state 2
# Observation 192 is in state 2
# Observation 193 is in state 2
# Observation 194 is in state 2
# Observation 195 is in state 2
# Observation 196 is in state 2
# Observation 197 is in state 2
# Observation 198 is in state 2
# Observation 199 is in state 2
# Observation 200 is in state 2
# Observation 201 is in state 2
# Observation 202 is in state 2
# Observation 203 is in state 2
# Observation 204 is in state 2
# Observation 205 is in state 2
# Observation 206 is in state 2
# Observation 207 is in state 2
# Observation 208 is in state 2
# Observation 209 is in state 2
# Observation 210 is in state 2
# Observation 211 is in state 2
# Observation 212 is in state 2
# Observation 213 is in state 2
# Observation 214 is in state 2
# Observation 215 is in state 1
# Observation 216 is in state 1
# Observation 217 is in state 1
# Observation 218 is in state 1
# Observation 219 is in state 1
# Observation 220 is in state 1
# Observation 221 is in state 1
# Observation 222 is in state 1
# Observation 223 is in state 1
# Observation 224 is in state 1
# Observation 225 is in state 2
# Observation 226 is in state 2
# Observation 227 is in state 2
# Observation 228 is in state 2
# Observation 229 is in state 2
# Observation 230 is in state 2
# Observation 231 is in state 2
# Observation 232 is in state 2
# Observation 233 is in state 2
# Observation 234 is in state 2
# Observation 235 is in state 2
# Observation 236 is in state 2
# Observation 237 is in state 2
# Observation 238 is in state 2
# Observation 239 is in state 2
# Observation 240 is in state 2
# Observation 241 is in state 2
# Observation 242 is in state 2
# Observation 243 is in state 2
# Observation 244 is in state 2
# Observation 245 is in state 2
# Observation 246 is in state 2
# Observation 247 is in state 2
# Observation 248 is in state 2
# Observation 249 is in state 2
# Observation 250 is in state 2
# Observation 251 is in state 2
# Observation 252 is in state 2
# Observation 253 is in state 2
# Observation 254 is in state 2
# Observation 255 is in state 2
# Observation 256 is in state 2
# Observation 257 is in state 2
# Observation 258 is in state 2
# Observation 259 is in state 2
# Observation 260 is in state 2
# Observation 261 is in state 2
# Observation 262 is in state 2
# Observation 263 is in state 2
# Observation 264 is in state 2
# Observation 265 is in state 2
# Observation 266 is in state 2
# Observation 267 is in state 2
# Observation 268 is in state 2
# Observation 269 is in state 2
# Observation 270 is in state 2
# Observation 271 is in state 2
# Observation 272 is in state 2
# Observation 273 is in state 2
# Observation 274 is in state 2
# Observation 275 is in state 2
# Observation 276 is in state 2
# Observation 277 is in state 2
# Observation 278 is in state 2
# Observation 279 is in state 2
# Observation 280 is in state 2
# Observation 281 is in state 2
# Observation 282 is in state 2
# Observation 283 is in state 2
# Observation 284 is in state 2
# Observation 285 is in state 2
# Observation 286 is in state 2
# Observation 287 is in state 2
# Observation 288 is in state 2
# Observation 289 is in state 2
# Observation 290 is in state 2
# Observation 291 is in state 2
# Observation 292 is in state 1
# Observation 293 is in state 1
# Observation 294 is in state 1
# Observation 295 is in state 1
# Observation 296 is in state 1
# Observation 297 is in state 1
# Observation 298 is in state 2
# Observation 299 is in state 2
# Observation 300 is in state 2
# Observation 301 is in state 2
# Observation 302 is in state 2
# Observation 303 is in state 2
# Observation 304 is in state 2
# Observation 305 is in state 2
# Observation 306 is in state 2
# Observation 307 is in state 2
# Observation 308 is in state 2
# Observation 309 is in state 2
# Observation 310 is in state 2
# Observation 311 is in state 2
# Observation 312 is in state 2
# Observation 313 is in state 2
# Observation 314 is in state 2
# Observation 315 is in state 2
# Observation 316 is in state 2
# Observation 317 is in state 2
# Observation 318 is in state 2
# Observation 319 is in state 2
# Observation 320 is in state 2
# Observation 321 is in state 2
# Observation 322 is in state 2
# Observation 323 is in state 2
# Observation 324 is in state 2
# Observation 325 is in state 2
# Observation 326 is in state 1
# Observation 327 is in state 1
# Observation 328 is in state 1
# Observation 329 is in state 1
# Observation 330 is in state 1
# Observation 331 is in state 1
# Observation 332 is in state 1
# Observation 333 is in state 1
# Observation 334 is in state 1
# Observation 335 is in state 1
# Observation 336 is in state 1
# Observation 337 is in state 1
# Observation 338 is in state 1
# Observation 339 is in state 1
# Observation 340 is in state 1
# Observation 341 is in state 1
# Observation 342 is in state 1
# Observation 343 is in state 1
# Observation 344 is in state 1
# Observation 345 is in state 1
# Observation 346 is in state 1
# Observation 347 is in state 1
# Observation 348 is in state 1
# Observation 349 is in state 1
# Observation 350 is in state 1
# Observation 351 is in state 1
# Observation 352 is in state 1
# Observation 353 is in state 1
# Observation 354 is in state 1
# Observation 355 is in state 2
# Observation 356 is in state 2
# Observation 357 is in state 2
# Observation 358 is in state 2
# Observation 359 is in state 2
# Observation 360 is in state 2
# Observation 361 is in state 2
# Observation 362 is in state 2
# Observation 363 is in state 2
# Observation 364 is in state 2
# Observation 365 is in state 2
# Observation 366 is in state 2
# Observation 367 is in state 2
# Observation 368 is in state 2
# Observation 369 is in state 2
# Observation 370 is in state 2
# Observation 371 is in state 2
# Observation 372 is in state 2
# Observation 373 is in state 2
# Observation 374 is in state 2
# Observation 375 is in state 2
# Observation 376 is in state 3
# Observation 377 is in state 3
# Observation 378 is in state 3
# Observation 379 is in state 3
# Observation 380 is in state 3
# Observation 381 is in state 3
# Observation 382 is in state 3
# Observation 383 is in state 3
# Observation 384 is in state 3
# Observation 385 is in state 3
# Observation 386 is in state 3
# Observation 387 is in state 3
# Observation 388 is in state 3
# Observation 389 is in state 3
# Observation 390 is in state 3
# Observation 391 is in state 3
# Observation 392 is in state 3
# Observation 393 is in state 3
# Observation 394 is in state 3
# Observation 395 is in state 3
# Observation 396 is in state 3
# Observation 397 is in state 2
# Observation 398 is in state 2
# Observation 399 is in state 2
# Observation 400 is in state 2
# Observation 401 is in state 2
# Observation 402 is in state 2
# Observation 403 is in state 2
# Observation 404 is in state 2
# Observation 405 is in state 2
# Observation 406 is in state 2
# Observation 407 is in state 2
# Observation 408 is in state 2
# Observation 409 is in state 2
# Observation 410 is in state 2
# Observation 411 is in state 2
# Observation 412 is in state 2
# Observation 413 is in state 2
# Observation 414 is in state 2
# Observation 415 is in state 2
# Observation 416 is in state 2
# Observation 417 is in state 2
# Observation 418 is in state 2
# Observation 419 is in state 2
# Observation 420 is in state 2
# Observation 421 is in state 2
# Observation 422 is in state 2
# Observation 423 is in state 2
# Observation 424 is in state 2
# Observation 425 is in state 2
# Observation 426 is in state 2
# Observation 427 is in state 2
# Observation 428 is in state 2
# Observation 429 is in state 2
# Observation 430 is in state 2
# Observation 431 is in state 2
# Observation 432 is in state 2
# Observation 433 is in state 2
# Observation 434 is in state 2
# Observation 435 is in state 2
# Observation 436 is in state 2
# Observation 437 is in state 2
# Observation 438 is in state 2
# Observation 439 is in state 2
# Observation 440 is in state 2
# Observation 441 is in state 2
# Observation 442 is in state 2
# Observation 443 is in state 2
# Observation 444 is in state 2
# Observation 445 is in state 2
# Observation 446 is in state 2
# Observation 447 is in state 2
# Observation 448 is in state 2
# Observation 449 is in state 2
# Observation 450 is in state 2
# Observation 451 is in state 2
# Observation 452 is in state 2
# Observation 453 is in state 2
# Observation 454 is in state 2
# Observation 455 is in state 2
# Observation 456 is in state 2
# Observation 457 is in state 2
# Observation 458 is in state 2
# Observation 459 is in state 2
# Observation 460 is in state 2
# Observation 461 is in state 2
# Observation 462 is in state 2
# Observation 463 is in state 2
# Observation 464 is in state 2
# Observation 465 is in state 2
# Observation 466 is in state 2
# Observation 467 is in state 3
# Observation 468 is in state 3
# Observation 469 is in state 3
# Observation 470 is in state 3
# Observation 471 is in state 3
# Observation 472 is in state 3
# Observation 473 is in state 3
# Observation 474 is in state 3
# Observation 475 is in state 3
# Observation 476 is in state 3
# Observation 477 is in state 3
# Observation 478 is in state 3
# Observation 479 is in state 3
# Observation 480 is in state 3
# Observation 481 is in state 3
# Observation 482 is in state 3
# Observation 483 is in state 3
# Observation 484 is in state 3
# Observation 485 is in state 3
# Observation 486 is in state 3
# Observation 487 is in state 3
# Observation 488 is in state 3
# Observation 489 is in state 2
# Observation 490 is in state 2
# Observation 491 is in state 2
# Observation 492 is in state 2
# Observation 493 is in state 2
# Observation 494 is in state 2
# Observation 495 is in state 2
# Observation 496 is in state 2
# Observation 497 is in state 2
# Observation 498 is in state 2
# Observation 499 is in state 2
# Observation 500 is in state 2
# Observation 501 is in state 2
# Observation 502 is in state 2
# Observation 503 is in state 2
# Observation 504 is in state 2
# Observation 505 is in state 2
# Observation 506 is in state 2
# Observation 507 is in state 2
# Observation 508 is in state 2
# Observation 509 is in state 2
# Observation 510 is in state 2
# Observation 511 is in state 2
# Observation 512 is in state 2
# Observation 513 is in state 2
# Observation 514 is in state 2
# Observation 515 is in state 2
# Observation 516 is in state 2
# Observation 517 is in state 2
# Observation 518 is in state 2
# Observation 519 is in state 2
# Observation 520 is in state 2
# Observation 521 is in state 2
# Observation 522 is in state 2
# Observation 523 is in state 2
# Observation 524 is in state 2
# Observation 525 is in state 2
# Observation 526 is in state 2
# Observation 527 is in state 2
# Observation 528 is in state 2
# Observation 529 is in state 2
# Observation 530 is in state 2
# Observation 531 is in state 2
# Observation 532 is in state 2
# Observation 533 is in state 2
# Observation 534 is in state 2
# Observation 535 is in state 2
# Observation 536 is in state 2
# Observation 537 is in state 2
# Observation 538 is in state 2
# Observation 539 is in state 2
# Observation 540 is in state 2
# Observation 541 is in state 2
# Observation 542 is in state 2
# Observation 543 is in state 2
# Observation 544 is in state 2
# Observation 545 is in state 2
# Observation 546 is in state 2
# Observation 547 is in state 2
# Observation 548 is in state 2
# Observation 549 is in state 2
# Observation 550 is in state 2
# Observation 551 is in state 2
# Observation 552 is in state 2
# Observation 553 is in state 2
# Observation 554 is in state 3
# Observation 555 is in state 3
# Observation 556 is in state 3
# Observation 557 is in state 3
# Observation 558 is in state 3
# Observation 559 is in state 3
# Observation 560 is in state 3
# Observation 561 is in state 3
# Observation 562 is in state 3
# Observation 563 is in state 3
# Observation 564 is in state 3
# Observation 565 is in state 3
# Observation 566 is in state 3
# Observation 567 is in state 3
# Observation 568 is in state 3
# Observation 569 is in state 3
# Observation 570 is in state 3
# Observation 571 is in state 3
# Observation 572 is in state 3
# Observation 573 is in state 3
# Observation 574 is in state 3
# Observation 575 is in state 3
# Observation 576 is in state 3
# Observation 577 is in state 3
# Observation 578 is in state 3
# Observation 579 is in state 3
# Observation 580 is in state 3
# Observation 581 is in state 3
# Observation 582 is in state 3
# Observation 583 is in state 3
# Observation 584 is in state 2
# Observation 585 is in state 2
# Observation 586 is in state 2
# Observation 587 is in state 2
# Observation 588 is in state 2
# Observation 589 is in state 2
# Observation 590 is in state 2
# Observation 591 is in state 2
# Observation 592 is in state 2
# Observation 593 is in state 2
# Observation 594 is in state 2
# Observation 595 is in state 2
# Observation 596 is in state 2
# Observation 597 is in state 2
# Observation 598 is in state 2
# Observation 599 is in state 2
# Observation 600 is in state 2
# Observation 601 is in state 2
# Observation 602 is in state 3
# Observation 603 is in state 3
# Observation 604 is in state 3
# Observation 605 is in state 3
# Observation 606 is in state 3
# Observation 607 is in state 3
# Observation 608 is in state 3
# Observation 609 is in state 3
# Observation 610 is in state 3
# Observation 611 is in state 3
# Observation 612 is in state 3
# Observation 613 is in state 2
# Observation 614 is in state 2
# Observation 615 is in state 2
# Observation 616 is in state 2
# Observation 617 is in state 2
# Observation 618 is in state 2
# Observation 619 is in state 2
# Observation 620 is in state 2
# Observation 621 is in state 2
# Observation 622 is in state 2
# Observation 623 is in state 2
# Observation 624 is in state 2
# Observation 625 is in state 2
# Observation 626 is in state 2
# Observation 627 is in state 2
# Observation 628 is in state 2
# Observation 629 is in state 2
# Observation 630 is in state 2
# Observation 631 is in state 2
# Observation 632 is in state 2
# Observation 633 is in state 2
# Observation 634 is in state 2
# Observation 635 is in state 2
# Observation 636 is in state 2
# Observation 637 is in state 2
# Observation 638 is in state 2
# Observation 639 is in state 3
# Observation 640 is in state 3
# Observation 641 is in state 3
# Observation 642 is in state 3
# Observation 643 is in state 3
# Observation 644 is in state 3
# Observation 645 is in state 3
# Observation 646 is in state 3
# Observation 647 is in state 3
# Observation 648 is in state 3
# Observation 649 is in state 3
# Observation 650 is in state 3
# Observation 651 is in state 3
# Observation 652 is in state 3
# Observation 653 is in state 3
# Observation 654 is in state 3
# Observation 655 is in state 3
# Observation 656 is in state 2
# Observation 657 is in state 2
# Observation 658 is in state 2
# Observation 659 is in state 2
# Observation 660 is in state 2
# Observation 661 is in state 2
# Observation 662 is in state 2
# Observation 663 is in state 2
# Observation 664 is in state 2
# Observation 665 is in state 2
# Observation 666 is in state 2
# Observation 667 is in state 2
# Observation 668 is in state 2
# Observation 669 is in state 2
# Observation 670 is in state 2
# Observation 671 is in state 2
# Observation 672 is in state 2
# Observation 673 is in state 2
# Observation 674 is in state 2
# Observation 675 is in state 2
# Observation 676 is in state 2
# Observation 677 is in state 2
# Observation 678 is in state 2
# Observation 679 is in state 2
# Observation 680 is in state 2
# Observation 681 is in state 2
# Observation 682 is in state 2
# Observation 683 is in state 2
# Observation 684 is in state 2
# Observation 685 is in state 2
# Observation 686 is in state 2
# Observation 687 is in state 2
# Observation 688 is in state 2
# Observation 689 is in state 2
# Observation 690 is in state 2
# Observation 691 is in state 2
# Observation 692 is in state 2
# Observation 693 is in state 2
# Observation 694 is in state 2
# Observation 695 is in state 2
# Observation 696 is in state 2
# Observation 697 is in state 2
# Observation 698 is in state 2
# Observation 699 is in state 2
# Observation 700 is in state 2
# Observation 701 is in state 2
# Observation 702 is in state 2
# Observation 703 is in state 2
# Observation 704 is in state 2
# Observation 705 is in state 2
# Observation 706 is in state 2
# Observation 707 is in state 2
# Observation 708 is in state 2
# Observation 709 is in state 2
# Observation 710 is in state 2
# Observation 711 is in state 2
# Observation 712 is in state 2
# Observation 713 is in state 2
# Observation 714 is in state 2
# Observation 715 is in state 3
# Observation 716 is in state 3
# Observation 717 is in state 3
# Observation 718 is in state 3
# Observation 719 is in state 3
# Observation 720 is in state 3
# Observation 721 is in state 3
# Observation 722 is in state 3
# Observation 723 is in state 3
# Observation 724 is in state 3
# Observation 725 is in state 3
# Observation 726 is in state 3
# Observation 727 is in state 3
# Observation 728 is in state 3
# Observation 729 is in state 3
# Observation 730 is in state 3
# Observation 731 is in state 3
# Observation 732 is in state 3
# Observation 733 is in state 3
# Observation 734 is in state 3
# Observation 735 is in state 3
# Observation 736 is in state 2
# Observation 737 is in state 2
# Observation 738 is in state 2
# Observation 739 is in state 2
# Observation 740 is in state 2
# Observation 741 is in state 2
# Observation 742 is in state 2
# Observation 743 is in state 2
# Observation 744 is in state 2
# Observation 745 is in state 2
# Observation 746 is in state 2
# Observation 747 is in state 2
# Observation 748 is in state 2
# Observation 749 is in state 2
# Observation 750 is in state 2
# Observation 751 is in state 2
# Observation 752 is in state 2
# Observation 753 is in state 2
# Observation 754 is in state 2
# Observation 755 is in state 2
# Observation 756 is in state 2
# Observation 757 is in state 2
# Observation 758 is in state 2
# Observation 759 is in state 2
# Observation 760 is in state 2
# Observation 761 is in state 2
# Observation 762 is in state 2
# Observation 763 is in state 2
# Observation 764 is in state 2
# Observation 765 is in state 2
# Observation 766 is in state 2
# Observation 767 is in state 2
# Observation 768 is in state 2
# Observation 769 is in state 3
# Observation 770 is in state 3
# Observation 771 is in state 3
# Observation 772 is in state 3
# Observation 773 is in state 3
# Observation 774 is in state 3
# Observation 775 is in state 3
# Observation 776 is in state 3
# Observation 777 is in state 3
# Observation 778 is in state 1
# Observation 779 is in state 1
# Observation 780 is in state 1
# Observation 781 is in state 1
# Observation 782 is in state 1
# Observation 783 is in state 1
# Observation 784 is in state 1
# Observation 785 is in state 1
# Observation 786 is in state 1
# Observation 787 is in state 1
# Observation 788 is in state 1
# Observation 789 is in state 1
# Observation 790 is in state 1
# Observation 791 is in state 1
# Observation 792 is in state 1
# Observation 793 is in state 1
# Observation 794 is in state 1
# Observation 795 is in state 1
# Observation 796 is in state 1
# Observation 797 is in state 1
# Observation 798 is in state 1
# Observation 799 is in state 1
# Observation 800 is in state 1
# Observation 801 is in state 1
# Observation 802 is in state 1
# Observation 803 is in state 1
# Observation 804 is in state 1
# Observation 805 is in state 1
# Observation 806 is in state 1
# Observation 807 is in state 1
# Observation 808 is in state 1
# Observation 809 is in state 1
# Observation 810 is in state 1
# Observation 811 is in state 1
# Observation 812 is in state 1
# Observation 813 is in state 1
# Observation 814 is in state 1
# Observation 815 is in state 1
# Observation 816 is in state 1
# Observation 817 is in state 1
# Observation 818 is in state 1
# Observation 819 is in state 1
# Observation 820 is in state 1
# Observation 821 is in state 1
# Observation 822 is in state 1
# Observation 823 is in state 1
# Observation 824 is in state 1
# Observation 825 is in state 1
# Observation 826 is in state 1
# Observation 827 is in state 1
# Observation 828 is in state 1
# Observation 829 is in state 1
# Observation 830 is in state 1
# Observation 831 is in state 1
# Observation 832 is in state 1
# Observation 833 is in state 1
# Observation 834 is in state 1
# Observation 835 is in state 1
# Observation 836 is in state 1
# Observation 837 is in state 1
# Observation 838 is in state 1
# Observation 839 is in state 1
# Observation 840 is in state 1
# Observation 841 is in state 1
# Observation 842 is in state 2
# Observation 843 is in state 2
# Observation 844 is in state 2
# Observation 845 is in state 2
# Observation 846 is in state 2
# Observation 847 is in state 2
# Observation 848 is in state 2
# Observation 849 is in state 2
# Observation 850 is in state 2
# Observation 851 is in state 2
# Observation 852 is in state 2
# Observation 853 is in state 2
# Observation 854 is in state 2
# Observation 855 is in state 2
# Observation 856 is in state 2
# Observation 857 is in state 2
# Observation 858 is in state 2
# Observation 859 is in state 2
# Observation 860 is in state 2
# Observation 861 is in state 2
# Observation 862 is in state 2
# Observation 863 is in state 2
# Observation 864 is in state 2
# Observation 865 is in state 2
# Observation 866 is in state 2
# Observation 867 is in state 2
# Observation 868 is in state 2
# Observation 869 is in state 2
# Observation 870 is in state 2
# Observation 871 is in state 2
# Observation 872 is in state 2
# Observation 873 is in state 2
# Observation 874 is in state 2
# Observation 875 is in state 2
# Observation 876 is in state 2
# Observation 877 is in state 2
# Observation 878 is in state 2
# Observation 879 is in state 2
# Observation 880 is in state 2
# Observation 881 is in state 2
# Observation 882 is in state 2
# Observation 883 is in state 2
# Observation 884 is in state 2
# Observation 885 is in state 1
# Observation 886 is in state 1
# Observation 887 is in state 1
# Observation 888 is in state 1
# Observation 889 is in state 1
# Observation 890 is in state 2
# Observation 891 is in state 2
# Observation 892 is in state 2
# Observation 893 is in state 2
# Observation 894 is in state 2
# Observation 895 is in state 2
# Observation 896 is in state 2
# Observation 897 is in state 2
# Observation 898 is in state 2
# Observation 899 is in state 2
# Observation 900 is in state 2
# Observation 901 is in state 2
# Observation 902 is in state 2
# Observation 903 is in state 2
# Observation 904 is in state 2
# Observation 905 is in state 1
# Observation 906 is in state 1
# Observation 907 is in state 1
# Observation 908 is in state 1
# Observation 909 is in state 1
# Observation 910 is in state 1
# Observation 911 is in state 1
# Observation 912 is in state 1
# Observation 913 is in state 1
# Observation 914 is in state 1
# Observation 915 is in state 1
# Observation 916 is in state 1
# Observation 917 is in state 1
# Observation 918 is in state 1
# Observation 919 is in state 1
# Observation 920 is in state 1
# Observation 921 is in state 1
# Observation 922 is in state 1
# Observation 923 is in state 1
# Observation 924 is in state 1
# Observation 925 is in state 1
# Observation 926 is in state 1
# Observation 927 is in state 1
# Observation 928 is in state 1
# Observation 929 is in state 1
# Observation 930 is in state 3
# Observation 931 is in state 3
# Observation 932 is in state 3
# Observation 933 is in state 3
# Observation 934 is in state 3
# Observation 935 is in state 3
# Observation 936 is in state 3
# Observation 937 is in state 3
# Observation 938 is in state 3
# Observation 939 is in state 3
# Observation 940 is in state 3
# Observation 941 is in state 3
# Observation 942 is in state 3
# Observation 943 is in state 3
# Observation 944 is in state 3
# Observation 945 is in state 3
# Observation 946 is in state 3
# Observation 947 is in state 3
# Observation 948 is in state 3
# Observation 949 is in state 3
# Observation 950 is in state 3
# Observation 951 is in state 3
# Observation 952 is in state 3
# Observation 953 is in state 3
# Observation 954 is in state 3
# Observation 955 is in state 3
# Observation 956 is in state 3
# Observation 957 is in state 3
# Observation 958 is in state 3
# Observation 959 is in state 3
# Observation 960 is in state 3
# Observation 961 is in state 3
# Observation 962 is in state 3
# Observation 963 is in state 3
# Observation 964 is in state 3
# Observation 965 is in state 3
# Observation 966 is in state 3
# Observation 967 is in state 2
# Observation 968 is in state 2
# Observation 969 is in state 2
# Observation 970 is in state 2
# Observation 971 is in state 2
# Observation 972 is in state 2
# Observation 973 is in state 2
# Observation 974 is in state 2
# Observation 975 is in state 2
# Observation 976 is in state 2
# Observation 977 is in state 2
# Observation 978 is in state 2
# Observation 979 is in state 2
# Observation 980 is in state 2
# Observation 981 is in state 2
# Observation 982 is in state 2
# Observation 983 is in state 2
# Observation 984 is in state 2
# Observation 985 is in state 2
# Observation 986 is in state 2
# Observation 987 is in state 2
# Observation 988 is in state 2
# Observation 989 is in state 2
# Observation 990 is in state 2
# Observation 991 is in state 2
# Observation 992 is in state 2
# Observation 993 is in state 2
# Observation 994 is in state 2
# Observation 995 is in state 2
# Observation 996 is in state 2
# Observation 997 is in state 2
# Observation 998 is in state 2
# Observation 999 is in state 2
# Observation 1000 is in state 2
# Observation 1001 is in state 2
# Observation 1002 is in state 2
# Observation 1003 is in state 2
# Observation 1004 is in state 2
# Observation 1005 is in state 2
# Observation 1006 is in state 2
# Observation 1007 is in state 2
# Observation 1008 is in state 2
# Observation 1009 is in state 2
# Observation 1010 is in state 2
# Observation 1011 is in state 2
# Observation 1012 is in state 2
# Observation 1013 is in state 2
# Observation 1014 is in state 2
# Observation 1015 is in state 2
# Observation 1016 is in state 2
# Observation 1017 is in state 2
# Observation 1018 is in state 2
# Observation 1019 is in state 2
# Observation 1020 is in state 3
# Observation 1021 is in state 3
# Observation 1022 is in state 3
# Observation 1023 is in state 3
# Observation 1024 is in state 3
# Observation 1025 is in state 3
# Observation 1026 is in state 3
# Observation 1027 is in state 3
# Observation 1028 is in state 3
# Observation 1029 is in state 3
# Observation 1030 is in state 3
# Observation 1031 is in state 3
# Observation 1032 is in state 3
# Observation 1033 is in state 3
# Observation 1034 is in state 3
# Observation 1035 is in state 3
# Observation 1036 is in state 3
# Observation 1037 is in state 3
# Observation 1038 is in state 3
# Observation 1039 is in state 3
# Observation 1040 is in state 3
# Observation 1041 is in state 3
# Observation 1042 is in state 3
# Observation 1043 is in state 3
# Observation 1044 is in state 3
# Observation 1045 is in state 3
# Observation 1046 is in state 3
# Observation 1047 is in state 3
# Observation 1048 is in state 2
# Observation 1049 is in state 2
# Observation 1050 is in state 2
# Observation 1051 is in state 2
# Observation 1052 is in state 2
# Observation 1053 is in state 2
# Observation 1054 is in state 2
# Observation 1055 is in state 2
# Observation 1056 is in state 2
# Observation 1057 is in state 2
# Observation 1058 is in state 2
# Observation 1059 is in state 2
# Observation 1060 is in state 2
# Observation 1061 is in state 2
# Observation 1062 is in state 2
# Observation 1063 is in state 2
# Observation 1064 is in state 2
# Observation 1065 is in state 2
# Observation 1066 is in state 2
# Observation 1067 is in state 2
# Observation 1068 is in state 2
# Observation 1069 is in state 2
# Observation 1070 is in state 2
# Observation 1071 is in state 1
# Observation 1072 is in state 1
# Observation 1073 is in state 1
# Observation 1074 is in state 1
# Observation 1075 is in state 1
# Observation 1076 is in state 1
# Observation 1077 is in state 1
# Observation 1078 is in state 1
# Observation 1079 is in state 1
# Observation 1080 is in state 1
# Observation 1081 is in state 1
# Observation 1082 is in state 2
# Observation 1083 is in state 2
# Observation 1084 is in state 2
# Observation 1085 is in state 2
# Observation 1086 is in state 2
# Observation 1087 is in state 2
# Observation 1088 is in state 2
# Observation 1089 is in state 2
# Observation 1090 is in state 2
# Observation 1091 is in state 2
# Observation 1092 is in state 2
# Observation 1093 is in state 2
# Observation 1094 is in state 2
# Observation 1095 is in state 2
# Observation 1096 is in state 2
# Observation 1097 is in state 2
# Observation 1098 is in state 2
# Observation 1099 is in state 2
# Observation 1100 is in state 2
# Observation 1101 is in state 3
# Observation 1102 is in state 3
# Observation 1103 is in state 3
# Observation 1104 is in state 3
# Observation 1105 is in state 3
# Observation 1106 is in state 3
# Observation 1107 is in state 3
# Observation 1108 is in state 3
# Observation 1109 is in state 3
# Observation 1110 is in state 3
# Observation 1111 is in state 3
# Observation 1112 is in state 3
# Observation 1113 is in state 3
# Observation 1114 is in state 3
# Observation 1115 is in state 3
# Observation 1116 is in state 3
# Observation 1117 is in state 3
# Observation 1118 is in state 3
# Observation 1119 is in state 3
# Observation 1120 is in state 3
# Observation 1121 is in state 3
# Observation 1122 is in state 3
# Observation 1123 is in state 3
# Observation 1124 is in state 3
# Observation 1125 is in state 3
# Observation 1126 is in state 3
# Observation 1127 is in state 3
# Observation 1128 is in state 3
# Observation 1129 is in state 3
# Observation 1130 is in state 3
# Observation 1131 is in state 3
# Observation 1132 is in state 3
# Observation 1133 is in state 3
# Observation 1134 is in state 3
# Observation 1135 is in state 3
# Observation 1136 is in state 3
# Observation 1137 is in state 3
# Observation 1138 is in state 2
# Observation 1139 is in state 2
# Observation 1140 is in state 2
# Observation 1141 is in state 2
# Observation 1142 is in state 2
# Observation 1143 is in state 2
# Observation 1144 is in state 2
# Observation 1145 is in state 2
# Observation 1146 is in state 2
# Observation 1147 is in state 2
# Observation 1148 is in state 2
# Observation 1149 is in state 2
# Observation 1150 is in state 2
# Observation 1151 is in state 2
# Observation 1152 is in state 2
# Observation 1153 is in state 2
# Observation 1154 is in state 2
# Observation 1155 is in state 2
# Observation 1156 is in state 2
# Observation 1157 is in state 2
# Observation 1158 is in state 2
# Observation 1159 is in state 2
# Observation 1160 is in state 2
# Observation 1161 is in state 2
# Observation 1162 is in state 2
# Observation 1163 is in state 2
# Observation 1164 is in state 2
# Observation 1165 is in state 2
# Observation 1166 is in state 2
# Observation 1167 is in state 2
# Observation 1168 is in state 2
# Observation 1169 is in state 2
# Observation 1170 is in state 2
# Observation 1171 is in state 2
# Observation 1172 is in state 2
# Observation 1173 is in state 2
# Observation 1174 is in state 2
# Observation 1175 is in state 2
# Observation 1176 is in state 2
# Observation 1177 is in state 2
# Observation 1178 is in state 2
# Observation 1179 is in state 2
# Observation 1180 is in state 2
# Observation 1181 is in state 2
# Observation 1182 is in state 2
# Observation 1183 is in state 3
# Observation 1184 is in state 3
# Observation 1185 is in state 3
# Observation 1186 is in state 3
# Observation 1187 is in state 3
# Observation 1188 is in state 3
# Observation 1189 is in state 3
# Observation 1190 is in state 3
# Observation 1191 is in state 3
# Observation 1192 is in state 3
# Observation 1193 is in state 3
# Observation 1194 is in state 3
# Observation 1195 is in state 3
# Observation 1196 is in state 3
# Observation 1197 is in state 3
# Observation 1198 is in state 3
# Observation 1199 is in state 3
# Observation 1200 is in state 3
# Observation 1201 is in state 3
# Observation 1202 is in state 3
# Observation 1203 is in state 2
# Observation 1204 is in state 2
# Observation 1205 is in state 2
# Observation 1206 is in state 2
# Observation 1207 is in state 2
# Observation 1208 is in state 2
# Observation 1209 is in state 2
# Observation 1210 is in state 2
# Observation 1211 is in state 2
# Observation 1212 is in state 2
# Observation 1213 is in state 2
# Observation 1214 is in state 2
# Observation 1215 is in state 2
# Observation 1216 is in state 2
# Observation 1217 is in state 2
# Observation 1218 is in state 2
# Observation 1219 is in state 2
# Observation 1220 is in state 2
# Observation 1221 is in state 2
# Observation 1222 is in state 2
# Observation 1223 is in state 2
# Observation 1224 is in state 2
# Observation 1225 is in state 2
# Observation 1226 is in state 2
# Observation 1227 is in state 2
# Observation 1228 is in state 2
# Observation 1229 is in state 2
# Observation 1230 is in state 2
# Observation 1231 is in state 2
# Observation 1232 is in state 2
# Observation 1233 is in state 2
# Observation 1234 is in state 2
# Observation 1235 is in state 2
# Observation 1236 is in state 2
# Observation 1237 is in state 2
# Observation 1238 is in state 2
# Observation 1239 is in state 2
# Observation 1240 is in state 2
# Observation 1241 is in state 2
# Observation 1242 is in state 2
# Observation 1243 is in state 2
# Observation 1244 is in state 2
# Observation 1245 is in state 2
# Observation 1246 is in state 2
# Observation 1247 is in state 2
# Observation 1248 is in state 2
# Observation 1249 is in state 2
# Observation 1250 is in state 2
# Observation 1251 is in state 2
# Observation 1252 is in state 2
# Observation 1253 is in state 2
# Observation 1254 is in state 2
# Observation 1255 is in state 2
# Observation 1256 is in state 2
# Observation 1257 is in state 2
# Observation 1258 is in state 2
# Observation 1259 is in state 2
# Observation 1260 is in state 2
# Observation 1261 is in state 2
# Observation 1262 is in state 2
# Observation 1263 is in state 2
# Observation 1264 is in state 2
# Observation 1265 is in state 2
# Observation 1266 is in state 2
# Observation 1267 is in state 2
# Observation 1268 is in state 2
# Observation 1269 is in state 2
# Observation 1270 is in state 2
# Observation 1271 is in state 3
# Observation 1272 is in state 3
# Observation 1273 is in state 3
# Observation 1274 is in state 3
# Observation 1275 is in state 3
# Observation 1276 is in state 3
# Observation 1277 is in state 3
# Observation 1278 is in state 3
# Observation 1279 is in state 3
# Observation 1280 is in state 3
# Observation 1281 is in state 3
# Observation 1282 is in state 3
# Observation 1283 is in state 3
# Observation 1284 is in state 3
# Observation 1285 is in state 3
# Observation 1286 is in state 3
# Observation 1287 is in state 3
# Observation 1288 is in state 3
# Observation 1289 is in state 3
# Observation 1290 is in state 3
# Observation 1291 is in state 3
# Observation 1292 is in state 2
# Observation 1293 is in state 2
# Observation 1294 is in state 2
# Observation 1295 is in state 2
# Observation 1296 is in state 2
# Observation 1297 is in state 2
# Observation 1298 is in state 2
# Observation 1299 is in state 2
# Observation 1300 is in state 2
# Observation 1301 is in state 2
# Observation 1302 is in state 2
# Observation 1303 is in state 2
# Observation 1304 is in state 2
# Observation 1305 is in state 2
# Observation 1306 is in state 2
# Observation 1307 is in state 2
# Observation 1308 is in state 2
# Observation 1309 is in state 2
# Observation 1310 is in state 2
# Observation 1311 is in state 2
# Observation 1312 is in state 2
# Observation 1313 is in state 2
# Observation 1314 is in state 2
# Observation 1315 is in state 2
# Observation 1316 is in state 2
# Observation 1317 is in state 2
# Observation 1318 is in state 2
# Observation 1319 is in state 2
# Observation 1320 is in state 2
# Observation 1321 is in state 2
# Observation 1322 is in state 2
# Observation 1323 is in state 2
# Observation 1324 is in state 2
# Observation 1325 is in state 2
# Observation 1326 is in state 2
# Observation 1327 is in state 2
# Observation 1328 is in state 2
# Observation 1329 is in state 2
# Observation 1330 is in state 2
# Observation 1331 is in state 2
# Observation 1332 is in state 2
# Observation 1333 is in state 2
# Observation 1334 is in state 2
# Observation 1335 is in state 2
# Observation 1336 is in state 2
# Observation 1337 is in state 2
# Observation 1338 is in state 2
# Observation 1339 is in state 2
# Observation 1340 is in state 2
# Observation 1341 is in state 2
# Observation 1342 is in state 2
# Observation 1343 is in state 2
# Observation 1344 is in state 2
# Observation 1345 is in state 2
# Observation 1346 is in state 2
# Observation 1347 is in state 2
# Observation 1348 is in state 2
# Observation 1349 is in state 2
# Observation 1350 is in state 2
# Observation 1351 is in state 2
# Observation 1352 is in state 2
# Observation 1353 is in state 2
# Observation 1354 is in state 2
# Observation 1355 is in state 2
# Observation 1356 is in state 2
# Observation 1357 is in state 2
# Observation 1358 is in state 2
# Observation 1359 is in state 2
# Observation 1360 is in state 2
# Observation 1361 is in state 2
# Observation 1362 is in state 2
# Observation 1363 is in state 2
# Observation 1364 is in state 2
# Observation 1365 is in state 1
# Observation 1366 is in state 1
# Observation 1367 is in state 1
# Observation 1368 is in state 1
# Observation 1369 is in state 1
# Observation 1370 is in state 1
# Observation 1371 is in state 1
# Observation 1372 is in state 1
# Observation 1373 is in state 1
# Observation 1374 is in state 1
# Observation 1375 is in state 1
# Observation 1376 is in state 1
# Observation 1377 is in state 1
# Observation 1378 is in state 1
# Observation 1379 is in state 1
# Observation 1380 is in state 1
# Observation 1381 is in state 1
# Observation 1382 is in state 1
# Observation 1383 is in state 1
# Observation 1384 is in state 1
# Observation 1385 is in state 1
# Observation 1386 is in state 1
# Observation 1387 is in state 1
# Observation 1388 is in state 1
# Observation 1389 is in state 1
# Observation 1390 is in state 1
# Observation 1391 is in state 1
# Observation 1392 is in state 1
# Observation 1393 is in state 1
# Observation 1394 is in state 1
# Observation 1395 is in state 1
# Observation 1396 is in state 1
# Observation 1397 is in state 1
# Observation 1398 is in state 1
# Observation 1399 is in state 1
# Observation 1400 is in state 1
# Observation 1401 is in state 1
# Observation 1402 is in state 1
# Observation 1403 is in state 1
# Observation 1404 is in state 1
# Observation 1405 is in state 2
# Observation 1406 is in state 2
# Observation 1407 is in state 2
# Observation 1408 is in state 2
# Observation 1409 is in state 2
# Observation 1410 is in state 2
# Observation 1411 is in state 2
# Observation 1412 is in state 2
# Observation 1413 is in state 2
# Observation 1414 is in state 2
# Observation 1415 is in state 2
# Observation 1416 is in state 2
# Observation 1417 is in state 2
# Observation 1418 is in state 2
# Observation 1419 is in state 2
# Observation 1420 is in state 2
# Observation 1421 is in state 2
# Observation 1422 is in state 2
# Observation 1423 is in state 2
# Observation 1424 is in state 2
# Observation 1425 is in state 2
# Observation 1426 is in state 2
# Observation 1427 is in state 2
# Observation 1428 is in state 2
# Observation 1429 is in state 2
# Observation 1430 is in state 2
# Observation 1431 is in state 2
# Observation 1432 is in state 2
# Observation 1433 is in state 2
# Observation 1434 is in state 2
# Observation 1435 is in state 1
# Observation 1436 is in state 1
# Observation 1437 is in state 1
# Observation 1438 is in state 1
# Observation 1439 is in state 1
# Observation 1440 is in state 1
# Observation 1441 is in state 1
# Observation 1442 is in state 1
# Observation 1443 is in state 1
# Observation 1444 is in state 1
# Observation 1445 is in state 1
# Observation 1446 is in state 1
# Observation 1447 is in state 1
# Observation 1448 is in state 1
# Observation 1449 is in state 1
# Observation 1450 is in state 1
# Observation 1451 is in state 1
# Observation 1452 is in state 1
# Observation 1453 is in state 1
# Observation 1454 is in state 1
# Observation 1455 is in state 1
# Observation 1456 is in state 1
# Observation 1457 is in state 1
# Observation 1458 is in state 1
# Observation 1459 is in state 1
# Observation 1460 is in state 1
# Observation 1461 is in state 1
# Observation 1462 is in state 1
# Observation 1463 is in state 1
# Observation 1464 is in state 1
# Observation 1465 is in state 1
# Observation 1466 is in state 1
# Observation 1467 is in state 1
# Observation 1468 is in state 1
# Observation 1469 is in state 1
# Observation 1470 is in state 3
# Observation 1471 is in state 3
# Observation 1472 is in state 3
# Observation 1473 is in state 3
# Observation 1474 is in state 3
# Observation 1475 is in state 3
# Observation 1476 is in state 3
# Observation 1477 is in state 3
# Observation 1478 is in state 3
# Observation 1479 is in state 3
# Observation 1480 is in state 3
# Observation 1481 is in state 3
# Observation 1482 is in state 3
# Observation 1483 is in state 3
# Observation 1484 is in state 3
# Observation 1485 is in state 3
# Observation 1486 is in state 3
# Observation 1487 is in state 3
# Observation 1488 is in state 3
# Observation 1489 is in state 3
# Observation 1490 is in state 3
# Observation 1491 is in state 3
# Observation 1492 is in state 3
# Observation 1493 is in state 3
# Observation 1494 is in state 3
# Observation 1495 is in state 3
# Observation 1496 is in state 3
# Observation 1497 is in state 3
# Observation 1498 is in state 3
# Observation 1499 is in state 3
# Observation 1500 is in state 3
# Observation 1501 is in state 3
# Observation 1502 is in state 3
# Observation 1503 is in state 3
# Observation 1504 is in state 2
# Observation 1505 is in state 2
# Observation 1506 is in state 2
# Observation 1507 is in state 2
# Observation 1508 is in state 2
# Observation 1509 is in state 2
# Observation 1510 is in state 2
# Observation 1511 is in state 2
# Observation 1512 is in state 2
# Observation 1513 is in state 2
# Observation 1514 is in state 2
# Observation 1515 is in state 2
# Observation 1516 is in state 2
# Observation 1517 is in state 2
# Observation 1518 is in state 2
# Observation 1519 is in state 2
# Observation 1520 is in state 2
# Observation 1521 is in state 2
# Observation 1522 is in state 2
# Observation 1523 is in state 2
# Observation 1524 is in state 2
# Observation 1525 is in state 2
# Observation 1526 is in state 2
# Observation 1527 is in state 2
# Observation 1528 is in state 2
# Observation 1529 is in state 2
# Observation 1530 is in state 2
# Observation 1531 is in state 2
# Observation 1532 is in state 2
# Observation 1533 is in state 2
# Observation 1534 is in state 2
# Observation 1535 is in state 2
# Observation 1536 is in state 2
# Observation 1537 is in state 2
# Observation 1538 is in state 2
# Observation 1539 is in state 2
# Observation 1540 is in state 2
# Observation 1541 is in state 2
# Observation 1542 is in state 2
# Observation 1543 is in state 2
# Observation 1544 is in state 2
# Observation 1545 is in state 2
# Observation 1546 is in state 2
# Observation 1547 is in state 2
# Observation 1548 is in state 2
# Observation 1549 is in state 2
# Observation 1550 is in state 2
# Observation 1551 is in state 2
# Observation 1552 is in state 2
# Observation 1553 is in state 2
# Observation 1554 is in state 2
# Observation 1555 is in state 3
# Observation 1556 is in state 3
# Observation 1557 is in state 3
# Observation 1558 is in state 3
# Observation 1559 is in state 3
# Observation 1560 is in state 3
# Observation 1561 is in state 3
# Observation 1562 is in state 3
# Observation 1563 is in state 3
# Observation 1564 is in state 3
# Observation 1565 is in state 3
# Observation 1566 is in state 3
# Observation 1567 is in state 3
# Observation 1568 is in state 3
# Observation 1569 is in state 3
# Observation 1570 is in state 3
# Observation 1571 is in state 3
# Observation 1572 is in state 3
# Observation 1573 is in state 2
# Observation 1574 is in state 2
# Observation 1575 is in state 2
# Observation 1576 is in state 2
# Observation 1577 is in state 2
# Observation 1578 is in state 2
# Observation 1579 is in state 2
# Observation 1580 is in state 2
# Observation 1581 is in state 2
# Observation 1582 is in state 2
# Observation 1583 is in state 2
# Observation 1584 is in state 2
# ...
# Observation 2869 is in state 3
# Observation 2870 is in state 3
# Observation 2871 is in state 3
# Observation 2872 is in state 3
# Observation 2873 is in state 3
# Observation 2874 is in state 3
# Observation 2875 is in state 3
# Observation 2876 is in state 3
# Observation 2877 is in state 3
# Observation 2878 is in state 3
# Observation 2879 is in state 3
# Observation 2880 is in state 3
# Observation 2881 is in state 3
# Observation 2882 is in state 3
# Observation 2883 is in state 3
# Observation 2884 is in state 3
# Observation 2885 is in state 3
# Observation 2886 is in state 3
# Observation 2887 is in state 3
# Observation 2888 is in state 3
# Observation 2889 is in state 3
# Observation 2890 is in state 3
# Observation 2891 is in state 3
# Observation 2892 is in state 3
# Observation 2893 is in state 3
# Observation 2894 is in state 3
# Observation 2895 is in state 3
# Observation 2896 is in state 3
# Observation 2897 is in state 2
# Observation 2898 is in state 2
# Observation 2899 is in state 2
# Observation 2900 is in state 2
# Observation 2901 is in state 2
# Observation 2902 is in state 2
# Observation 2903 is in state 2
# Observation 2904 is in state 3
# Observation 2905 is in state 3
# Observation 2906 is in state 3
# Observation 2907 is in state 3
# Observation 2908 is in state 3
# Observation 2909 is in state 3
# Observation 2910 is in state 3
# Observation 2911 is in state 3
# Observation 2912 is in state 3
# Observation 2913 is in state 3
# Observation 2914 is in state 3
# Observation 2915 is in state 3
# Observation 2916 is in state 3
# Observation 2917 is in state 3
# Observation 2918 is in state 3
# Observation 2919 is in state 3
# Observation 2920 is in state 3
# Observation 2921 is in state 3
# Observation 2922 is in state 3
# Observation 2923 is in state 3
# Observation 2924 is in state 3
# Observation 2925 is in state 3
# Observation 2926 is in state 3
# Observation 2927 is in state 3
# Observation 2928 is in state 3
# Observation 2929 is in state 3
# Observation 2930 is in state 3
# Observation 2931 is in state 3
# Observation 2932 is in state 3
# Observation 2933 is in state 3
# Observation 2934 is in state 3
# Observation 2935 is in state 3
# Observation 2936 is in state 3
# Observation 2937 is in state 3
# Observation 2938 is in state 3
# Observation 2939 is in state 3
# Observation 2940 is in state 3
# Observation 2941 is in state 3
# Observation 2942 is in state 3
# Observation 2943 is in state 3
# Observation 2944 is in state 3
# Observation 2945 is in state 3
# Observation 2946 is in state 3
# Observation 2947 is in state 3
# Observation 2948 is in state 3
# Observation 2949 is in state 3
# Observation 2950 is in state 3
# Observation 2951 is in state 3
# Observation 2952 is in state 3
# Observation 2953 is in state 3
# Observation 2954 is in state 3
# Observation 2955 is in state 3
# Observation 2956 is in state 3
# Observation 2957 is in state 3
# Observation 2958 is in state 3
# Observation 2959 is in state 3
# Observation 2960 is in state 3
# Observation 2961 is in state 3
# Observation 2962 is in state 3
# Observation 2963 is in state 3
# Observation 2964 is in state 3
# Observation 2965 is in state 3
# Observation 2966 is in state 3
# Observation 2967 is in state 3
# Observation 2968 is in state 3
# Observation 2969 is in state 3
# Observation 2970 is in state 2
# Observation 2971 is in state 2
# Observation 2972 is in state 2
# Observation 2973 is in state 2
# Observation 2974 is in state 2
# Observation 2975 is in state 2
# Observation 2976 is in state 2
# Observation 2977 is in state 2
# Observation 2978 is in state 2
# Observation 2979 is in state 2
# Observation 2980 is in state 1
# Observation 2981 is in state 1
# Observation 2982 is in state 1
# Observation 2983 is in state 2
# Observation 2984 is in state 2
# Observation 2985 is in state 2
# Observation 2986 is in state 2
# Observation 2987 is in state 3
# Observation 2988 is in state 3
# Observation 2989 is in state 3
# Observation 2990 is in state 3
# Observation 2991 is in state 3
# Observation 2992 is in state 3
# Observation 2993 is in state 3
# Observation 2994 is in state 3
# Observation 2995 is in state 3
# Observation 2996 is in state 3
# Observation 2997 is in state 3
# Observation 2998 is in state 3
# Observation 2999 is in state 3
# Observation 3000 is in state 3
# Observation 3001 is in state 3
# Observation 3002 is in state 3
# Observation 3003 is in state 3
# Observation 3004 is in state 3
# Observation 3005 is in state 3
# Observation 3006 is in state 3
# Observation 3007 is in state 3
# Observation 3008 is in state 3
# Observation 3009 is in state 3
# Observation 3010 is in state 3
# Observation 3011 is in state 3
# Observation 3012 is in state 3
# Observation 3013 is in state 3
# Observation 3014 is in state 3
# Observation 3015 is in state 3
# Observation 3016 is in state 3
# Observation 3017 is in state 3
# Observation 3018 is in state 3
# Observation 3019 is in state 3
# Observation 3020 is in state 3
# Observation 3021 is in state 3
# Observation 3022 is in state 3
# Observation 3023 is in state 3
# Observation 3024 is in state 3
# Observation 3025 is in state 3
# Observation 3026 is in state 2
# Observation 3027 is in state 2
# Observation 3028 is in state 2
# Observation 3029 is in state 2
# Observation 3030 is in state 2
# Observation 3031 is in state 2
# Observation 3032 is in state 2
# Observation 3033 is in state 2
# Observation 3034 is in state 2
# Observation 3035 is in state 2
# Observation 3036 is in state 2
# Observation 3037 is in state 2
# Observation 3038 is in state 2
# Observation 3039 is in state 2
# Observation 3040 is in state 2
# Observation 3041 is in state 2
# Observation 3042 is in state 2
# Observation 3043 is in state 2
# Observation 3044 is in state 2
# Observation 3045 is in state 2
# Observation 3046 is in state 2
# Observation 3047 is in state 2
# Observation 3048 is in state 2
# Observation 3049 is in state 2
# Observation 3050 is in state 2
# Observation 3051 is in state 2
# Observation 3052 is in state 3
# Observation 3053 is in state 3
# Observation 3054 is in state 3
# Observation 3055 is in state 3
# Observation 3056 is in state 3
# Observation 3057 is in state 3
# Observation 3058 is in state 3
# Observation 3059 is in state 3
# Observation 3060 is in state 3
# Observation 3061 is in state 3
# Observation 3062 is in state 3
# Observation 3063 is in state 3
# Observation 3064 is in state 3
# Observation 3065 is in state 3
# Observation 3066 is in state 3
# Observation 3067 is in state 3
# Observation 3068 is in state 3
# Observation 3069 is in state 3
# Observation 3070 is in state 3
# Observation 3071 is in state 3
# Observation 3072 is in state 1
# Observation 3073 is in state 1
# Observation 3074 is in state 1
# Observation 3075 is in state 1
# Observation 3076 is in state 1
# Observation 3077 is in state 1
# Observation 3078 is in state 1
# Observation 3079 is in state 1
# Observation 3080 is in state 3
# Observation 3081 is in state 3
# Observation 3082 is in state 3
# Observation 3083 is in state 3
# Observation 3084 is in state 3
# Observation 3085 is in state 3
# Observation 3086 is in state 3
# Observation 3087 is in state 3
# Observation 3088 is in state 3
# Observation 3089 is in state 3
# Observation 3090 is in state 3
# Observation 3091 is in state 3
# Observation 3092 is in state 3
# Observation 3093 is in state 3
# Observation 3094 is in state 3
# Observation 3095 is in state 3
# Observation 3096 is in state 2
# Observation 3097 is in state 2
# Observation 3098 is in state 2
# Observation 3099 is in state 2
# Observation 3100 is in state 2
# Observation 3101 is in state 2
# Observation 3102 is in state 2
# Observation 3103 is in state 2
# Observation 3104 is in state 2
# Observation 3105 is in state 2
# Observation 3106 is in state 2
# Observation 3107 is in state 2
# Observation 3108 is in state 2
# Observation 3109 is in state 2
# Observation 3110 is in state 2
# Observation 3111 is in state 2
# Observation 3112 is in state 2
# Observation 3113 is in state 2
# Observation 3114 is in state 2
# Observation 3115 is in state 2
# Observation 3116 is in state 2
# Observation 3117 is in state 2
# Observation 3118 is in state 2
# Observation 3119 is in state 3
# Observation 3120 is in state 3
# Observation 3121 is in state 3
# Observation 3122 is in state 3
# Observation 3123 is in state 3
# Observation 3124 is in state 3
# Observation 3125 is in state 3
# Observation 3126 is in state 3
# Observation 3127 is in state 3
# Observation 3128 is in state 2
# Observation 3129 is in state 2
# Observation 3130 is in state 2
# Observation 3131 is in state 2
# Observation 3132 is in state 2
# Observation 3133 is in state 2
# Observation 3134 is in state 2
# Observation 3135 is in state 3
# Observation 3136 is in state 3
# Observation 3137 is in state 3
# Observation 3138 is in state 3
# Observation 3139 is in state 3
# Observation 3140 is in state 3
# Observation 3141 is in state 3
# Observation 3142 is in state 3
# Observation 3143 is in state 3
# Observation 3144 is in state 3
# Observation 3145 is in state 3
# Observation 3146 is in state 3
# Observation 3147 is in state 3
# Observation 3148 is in state 3
# Observation 3149 is in state 3
# Observation 3150 is in state 3
# Observation 3151 is in state 3
# Observation 3152 is in state 3
# Observation 3153 is in state 3
# Observation 3154 is in state 3
# Observation 3155 is in state 3
# Observation 3156 is in state 3
# Observation 3157 is in state 3
# Observation 3158 is in state 3
# Observation 3159 is in state 3
# Observation 3160 is in state 3
# Observation 3161 is in state 3
# Observation 3162 is in state 3
# Observation 3163 is in state 3
# Observation 3164 is in state 3
# Observation 3165 is in state 3
# Observation 3166 is in state 3
# Observation 3167 is in state 3
# Observation 3168 is in state 3
# Observation 3169 is in state 3
# Observation 3170 is in state 3
# Observation 3171 is in state 3
# Observation 3172 is in state 3
# Observation 3173 is in state 3
# Observation 3174 is in state 3
# Observation 3175 is in state 3
# Observation 3176 is in state 3
# Observation 3177 is in state 3
# Observation 3178 is in state 3
# Observation 3179 is in state 3
# Observation 3180 is in state 3
# Observation 3181 is in state 3
# Observation 3182 is in state 3
# Observation 3183 is in state 3
# Observation 3184 is in state 3
# Observation 3185 is in state 3
# Observation 3186 is in state 3
# Observation 3187 is in state 3
# Observation 3188 is in state 3
# Observation 3189 is in state 3
# Observation 3190 is in state 3
# Observation 3191 is in state 3
# Observation 3192 is in state 3
# Observation 3193 is in state 3
# Observation 3194 is in state 3
# Observation 3195 is in state 3
# Observation 3196 is in state 3
# Observation 3197 is in state 3
# Observation 3198 is in state 3
# Observation 3199 is in state 3
# Observation 3200 is in state 3
# Observation 3201 is in state 3
# Observation 3202 is in state 3
# Observation 3203 is in state 3
# Observation 3204 is in state 3
# Observation 3205 is in state 3
# Observation 3206 is in state 3
# Observation 3207 is in state 3
# Observation 3208 is in state 3
# Observation 3209 is in state 3
# Observation 3210 is in state 3
# Observation 3211 is in state 3
# Observation 3212 is in state 3
# Observation 3213 is in state 3
# Observation 3214 is in state 3
# Observation 3215 is in state 3
# Observation 3216 is in state 3
# Observation 3217 is in state 3
# Observation 3218 is in state 1
# Observation 3219 is in state 1
# Observation 3220 is in state 1
# Observation 3221 is in state 1
# Observation 3222 is in state 1
# Observation 3223 is in state 1
# Observation 3224 is in state 1
# Observation 3225 is in state 1
# Observation 3226 is in state 1
# Observation 3227 is in state 1
# Observation 3228 is in state 1
# Observation 3229 is in state 3
# Observation 3230 is in state 3
# Observation 3231 is in state 3
# Observation 3232 is in state 3
# Observation 3233 is in state 3
# Observation 3234 is in state 3
# Observation 3235 is in state 3
# Observation 3236 is in state 3
# Observation 3237 is in state 3
# Observation 3238 is in state 3
# Observation 3239 is in state 3
# Observation 3240 is in state 2
# Observation 3241 is in state 2
# Observation 3242 is in state 1
# Observation 3243 is in state 1
# Observation 3244 is in state 1
# Observation 3245 is in state 1
# Observation 3246 is in state 3
# Observation 3247 is in state 3
# Observation 3248 is in state 3
# Observation 3249 is in state 3
# Observation 3250 is in state 3
# Observation 3251 is in state 3
# Observation 3252 is in state 3
# Observation 3253 is in state 3
# Observation 3254 is in state 3
# Observation 3255 is in state 3
# Observation 3256 is in state 1
# Observation 3257 is in state 1
# Observation 3258 is in state 1
# Observation 3259 is in state 1
# Observation 3260 is in state 1
# Observation 3261 is in state 1
# Observation 3262 is in state 1
# Observation 3263 is in state 1
# Observation 3264 is in state 2
# Observation 3265 is in state 2
# Observation 3266 is in state 2
# Observation 3267 is in state 2
# Observation 3268 is in state 2
# Observation 3269 is in state 2
# Observation 3270 is in state 2
# Observation 3271 is in state 2
# Observation 3272 is in state 2
# Observation 3273 is in state 2
# Observation 3274 is in state 2
# Observation 3275 is in state 2
# Observation 3276 is in state 2
# Observation 3277 is in state 2
# Observation 3278 is in state 2
# Observation 3279 is in state 2
# Observation 3280 is in state 2
# Observation 3281 is in state 2
# Observation 3282 is in state 2
# Observation 3283 is in state 3
# Observation 3284 is in state 3
# Observation 3285 is in state 3
# Observation 3286 is in state 3
# Observation 3287 is in state 3
# Observation 3288 is in state 3
# Observation 3289 is in state 3
# Observation 3290 is in state 3
# Observation 3291 is in state 3
# Observation 3292 is in state 3
# Observation 3293 is in state 3
# Observation 3294 is in state 3
# Observation 3295 is in state 3
# Observation 3296 is in state 3
# Observation 3297 is in state 3
# Observation 3298 is in state 3
# Observation 3299 is in state 3
# Observation 3300 is in state 3
# Observation 3301 is in state 3
# Observation 3302 is in state 3
# Observation 3303 is in state 3
# Observation 3304 is in state 3
# Observation 3305 is in state 3
# Observation 3306 is in state 3
# Observation 3307 is in state 3
# Observation 3308 is in state 3
# Observation 3309 is in state 3
# Observation 3310 is in state 3
# Observation 3311 is in state 3
# Observation 3312 is in state 3
# Observation 3313 is in state 3
# Observation 3314 is in state 3
# Observation 3315 is in state 3
# Observation 3316 is in state 3
# Observation 3317 is in state 3
# Observation 3318 is in state 3
# Observation 3319 is in state 3
# Observation 3320 is in state 3
# Observation 3321 is in state 3
# Observation 3322 is in state 3
# Observation 3323 is in state 3
# Observation 3324 is in state 3
# Observation 3325 is in state 3
# Observation 3326 is in state 3
# Observation 3327 is in state 3
# Observation 3328 is in state 3
# Observation 3329 is in state 3
# Observation 3330 is in state 3
# Observation 3331 is in state 3
# Observation 3332 is in state 3
# Observation 3333 is in state 3
# Observation 3334 is in state 3
# Observation 3335 is in state 3
# Observation 3336 is in state 3
# Observation 3337 is in state 3
# Observation 3338 is in state 3
# Observation 3339 is in state 3
# Observation 3340 is in state 3
# Observation 3341 is in state 3
# Observation 3342 is in state 3
# Observation 3343 is in state 3
# Observation 3344 is in state 3
# Observation 3345 is in state 3
# Observation 3346 is in state 3
# Observation 3347 is in state 3
# Observation 3348 is in state 3
# Observation 3349 is in state 3
# Observation 3350 is in state 3
# Observation 3351 is in state 3
# Observation 3352 is in state 3
# Observation 3353 is in state 3
# Observation 3354 is in state 3
# Observation 3355 is in state 3
# Observation 3356 is in state 3
# Observation 3357 is in state 3
# Observation 3358 is in state 3
# Observation 3359 is in state 3
# Observation 3360 is in state 3
# Observation 3361 is in state 3
# Observation 3362 is in state 3
# Observation 3363 is in state 3
# Observation 3364 is in state 3
# Observation 3365 is in state 3
# Observation 3366 is in state 3
# Observation 3367 is in state 3
# Observation 3368 is in state 3
# Observation 3369 is in state 3
# Observation 3370 is in state 3
# Observation 3371 is in state 3
# Observation 3372 is in state 3
# Observation 3373 is in state 3
# Observation 3374 is in state 3
# Observation 3375 is in state 3
# Observation 3376 is in state 3
# Observation 3377 is in state 3
# Observation 3378 is in state 3
# Observation 3379 is in state 3
# Observation 3380 is in state 3
# Observation 3381 is in state 3
# Observation 3382 is in state 2
# Observation 3383 is in state 2
# Observation 3384 is in state 2

# %%
plt.hist(df['filtered_states'])
# Out:
# (array([ 815.,    0.,    0.,    0.,    0., 1551.,    0.,    0.,    0.,
#         1018.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# Set up the figure and axes
# creating grid for subplots
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(6)
 
ax1 = plt.subplot2grid(shape=(4, 3), loc=(0, 0), colspan=3, rowspan=2)
ax2 = plt.subplot2grid(shape=(4, 3), loc=(2, 0), colspan=2, rowspan=1)
ax3 = plt.subplot2grid(shape=(4, 3), loc=(2, 2), rowspan=2)
# ax4 = plt.subplot2grid((4, 3), (3, 0))
ax5 = plt.subplot2grid((4, 3), (3, 0), colspan=2,rowspan=1)

############## plot the time series with states #################
# Plot speed as a line plot
ax1.plot(np.arange(len(df)),df.enhanced_speed*3.6, color='blue', label='Speed')

# Plot heart rate as a line plot
ax1.plot(np.arange(len(df)),df.heart_rate, color='red', label='Heart Rate')
ax1.legend()

# Get unique states and assign a color to each state
df.reset_index(drop=True,inplace=True)
unique_states = df.filtered_states.unique()
colors = plt.cm.get_cmap('Set1', len(unique_states))

# Plot filtered state as a horizontal line underneath the speed line
current_state = df.filtered_states[0]
start = 0

for i in range(1, len(df.filtered_states)):
    if df.filtered_states[i] != current_state:
        ax1.hlines(current_state, start, i, colors=colors(current_state), label=f'State {current_state+1}')
        current_state = df.filtered_states[i]
        start = i

# Add legend and labels
ax1.set_xlabel('Time')
ax1.set_ylabel('Value')


########### plot the speed hist ############

# Create a distplot of the speed variable
sns.histplot(df.enhanced_speed*3.6, bins='auto',kde=True, ax=ax2)

# Set the labels and title
plt.xlabel('Speed')
plt.ylabel('Density')
plt.title('Distribution of Speed')


########### plot the HR hist ############

# Create a distplot of the speed variable
sns.histplot(df.heart_rate, bins='auto',kde=True, ax=ax5, color='red')

# Set the labels and title
plt.xlabel('beats/min')
plt.ylabel('Density')
plt.title('Distribution of HR')

########### plot the hmm hist ############

# Create a distplot of the speed variable
ax3.hist(df.filtered_states)

# Set the labels and title
plt.xlabel('states')
plt.ylabel('count')
# Out:
# /var/folders/r6/k_cdzkx14flddy2y0tvhd57r0000gn/T/ipykernel_78073/2933464568.py:26: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('Set1', len(unique_states))
# Text(0, 0.5, 'count')

# %%
fig, ax = plt.subplots(1,1,figsize=(18,8))



states = df.filtered_states.to_numpy()

# Define a colormap to use
color_map = {
    0: 'red',
    1: 'green',
    2: 'blue',
    3: 'yellow'
}

# Add background colors
for i in range(len(df)):
    ax.axvspan(i-0.5, i+0.5, facecolor=color_map[states[i]], alpha=0.3)
ax.plot(np.arange(len(df)),df.enhanced_speed, color='k',linewidth=2)

# %%
df.groupby('filtered_states').mean()
# Out:
#                  enhanced_speed  heart_rate  elevation_change
# filtered_states
# 0                      8.505811  145.100993         -0.842715
# 1                      8.114713  130.278396          2.346102
# 2                     10.539146  166.841432          1.144501
# 3                      7.229996  131.858333         -5.420833

# %% [markdown]
# # swimming

# %%
import fitparse
from tqdm import tqdm
import os

# %%
df_sel['time_diff'] = df_sel['total_elapsed_time'].diff().abs()
df['cadence_diff'] = df['avg_swimming_cadence'].diff().abs()

# calculate the average time difference
avg_time_diff = df_sel['time_diff'].mean()

# identify the rows where the time difference is much greater than the average and swimming cadence is still similar
mask = ((df_sel['time_diff'] > 5) & (df_sel['cadence_diff'] <5))

# get the indices of the start of each pair
starts = df_sel.index[mask]

# calculate the average time for each pair and assign it to both rows
for start in starts:
    avg_time = df_sel.loc[start:start+1, 'total_elapsed_time'].mean()
    df_sel.loc[start:start+1, 'total_elapsed_time'] = avg_time

# delete the 'time_diff' column as it's no longer needed
df_sel.drop('time_diff', axis=1, inplace=True)

# %%
plt.plot(df_sel.loc[df.lap_nr==36].iloc[:,0:20]['total_elapsed_time'][:-1])
plt.plot(df.loc[df.lap_nr==36].iloc[:,0:20]['total_elapsed_time'][:-1])

# %%
# Reshape the dataframe
df_plot = df.melt(id_vars=['elapsed_time'], value_vars=['avg_speed'], var_name='metric', value_name='value')
